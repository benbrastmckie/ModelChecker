# %% [markdown]
# # Counterfactual Theory Demo Notebook
#
# This notebook demonstrates counterfactual logic examples from the default theory. It includes various countermodels showing invalid arguments and theorems showing valid arguments in counterfactual logic.

# %%
# Add parent directory to Python path to ensure module imports work
import sys
import os

# Add parent directories to path for proper imports
current_dir = os.path.dirname(os.path.abspath('.'))
parent_dir = os.path.dirname(current_dir)
parent_parent_dir = os.path.dirname(parent_dir)
parent_parent_parent_dir = os.path.dirname(parent_parent_dir)
parent_parent_parent_parent_dir = os.path.dirname(parent_parent_parent_dir)

# Add all possible parent paths to ensure the module is found
for path in [current_dir, parent_dir, parent_parent_dir, parent_parent_parent_dir, parent_parent_parent_parent_dir]:
    if path not in sys.path:
        sys.path.insert(0, path)

# Print current path to help with debugging
print(f"Current directory: {os.getcwd()}")
print(f"Python path: {sys.path}")
# Out:
# Current directory: /home/benjamin/Documents/Philosophy/Projects/ModelChecker/Code/src/model_checker/theory_lib/default/notebooks
# Python path: ['/home/benjamin/Documents/Philosophy/Projects/ModelChecker/Code/src/model_checker', '/home/benjamin/Documents/Philosophy/Projects/ModelChecker/Code/src/model_checker/theory_lib', '/home/benjamin/Documents/Philosophy/Projects/ModelChecker/Code/src/model_checker/theory_lib/default', '/home/benjamin/Documents/Philosophy/Projects/ModelChecker/Code', '/home/benjamin/Documents/Philosophy/Projects/ModelChecker/Code/src', '', '/nix/store/h3i0acpmr8mrjx07519xxmidv8mpax4y-python3-3.12.5/lib/python3.12/site-packages', '/nix/store/m3q9aavsms4fcj0n1x5w1g6cn60h0hc0-z3-solver-4.8.17-python/lib/python3.12/site-packages', '/nix/store/l7idy2qiiv0v0b6khfjvz3l5k6mnm47l-python3.12-setuptools-72.1.0/lib/python3.12/site-packages', '/nix/store/gam79wgc54sn8yyw2xkrqkf93v5lwaz1-python3.12-pip-24.0/lib/python3.12/site-packages', '/nix/store/w0ls6v4n3wb4jzriddxz4khx56dfmnmq-python3.12-networkx-3.3/lib/python3.12/site-packages', '/nix/store/99hl269v1igvjbp1znfk5jcarhzgy822-python3-3.12.8/lib/python312.zip', '/nix/store/99hl269v1igvjbp1znfk5jcarhzgy822-python3-3.12.8/lib/python3.12', '/nix/store/99hl269v1igvjbp1znfk5jcarhzgy822-python3-3.12.8/lib/python3.12/lib-dynload', '/nix/store/99hl269v1igvjbp1znfk5jcarhzgy822-python3-3.12.8/lib/python3.12/site-packages', '/nix/store/90r7m6gpnw5i5y30qq56zci99slfrfp6-python3-3.12.8-env/lib/python3.12/site-packages']

# %%
import model_checker
from model_checker.theory_lib import default
from model_checker.theory_lib.default.examples import counterfactual

# %% [markdown]
# ## Setup
#
# First, let's set up the basic components we need for model checking.

# %%
# Import operators
operators = default.default_operators

# Get default settings
default_settings = default.Semantics.DEFAULT_EXAMPLE_SETTINGS

# Define general settings for display
general_settings = {
    "print_constraints": False,
    "print_impossible": True,
    "print_z3": False,
    "save_output": False,
    "maximize": False,
}

# Update default settings with general settings
default_settings.update(general_settings)

# %% [markdown]
# ## Helper Function
#
# Let's create a helper function to run our examples.

# %%
def run_example(example, name):
    """Run a specific example and display the results.
    
    Args:
        example: The example to run (list containing premises, conclusions, settings)
        name: The name of the example
    """
    premises, conclusions, settings = example
    
    # Create syntax object
    syntax = model_checker.syntactic.Syntax(premises, conclusions, operators)
    
    # Update default settings with example-specific settings and general settings
    example_settings = default_settings.copy()
    example_settings.update(settings)
    
    # Ensure print_impossible is set
    if 'print_impossible' not in example_settings:
        example_settings['print_impossible'] = True
    
    # Create semantics
    semantics = default.Semantics(example_settings)
    proposition_class = default.Proposition
    
    # Create model constraints
    model_constraints = model_checker.model.ModelConstraints(example_settings, syntax, semantics, proposition_class)
    
    # Create model structure
    model_structure = default.ModelStructure(model_constraints, example_settings)
    
    # Interpret sentences before printing
    sentences = model_structure.premises + model_structure.conclusions
    model_structure.interpret(sentences)
    
    # Print results
    model_structure.print_all(example_settings, name, "Default Semantics")

# %% [markdown]
# ## Countermodels
#
# Let's examine some key countermodels from counterfactual logic.

# %% [markdown]
# ### CF_CM_1: Counterfactual Antecedent Strengthening

# %%
run_example(counterfactual.CF_CM_1_example, "Counterfactual Antecedent Strengthening")
# Out:
# ========================================
#
# EXAMPLE Counterfactual Antecedent Strengthening: there is a countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
# Premises:
# 1. \neg A
# 2. (A \boxright C)
#
# Conclusion:
# 3. ((A \wedge B) \boxright C)
#
# Z3 Run Time: 0.0248 seconds
#
# ========================================
# State Space:
#   #b0000 = □
#   #b0001 = a
#   #b0010 = b
#   #b0011 = a.b (impossible)
#   #b0100 = c
#   #b0101 = a.c (world)
#   #b0110 = b.c (impossible)
#   #b0111 = a.b.c (impossible)
#   #b1000 = d
#   #b1001 = a.d (world)
#   #b1010 = b.d (world)
#   #b1011 = a.b.d (impossible)
#   #b1100 = c.d (impossible)
#   #b1101 = a.c.d (impossible)
#   #b1110 = b.c.d (impossible)
#   #b1111 = a.b.c.d (impossible)
#
# The evaluation world is: a.c
#
# INTERPRETED PREMISES:
#
# 1.  |\neg A| = < {a.c}, {d} >  (True in a.c)
#       |A| = < {d}, {a.c} >  (False in a.c)
#
# 2.  |(A \boxright C)| = < {□}, ∅ >  (True in a.c)
#       |A| = < {d}, {a.c} >  (False in a.c)
#       |A|-alternatives to a.c = {a.d}
#         |C| = < {a.c, a.c.d, a.d}, {b.d} >  (True in a.d)
#
# INTERPRETED CONCLUSION:
#
# 3.  |((A \wedge B) \boxright C)| = < ∅, {□} >  (False in a.c)
#       |(A \wedge B)| = < {a.b.c.d, a.b.d, b.d}, {a, a.c, a.c.d} >  (False in a.c)
#         |A| = < {d}, {a.c} >  (False in a.c)
#         |B| = < {a.b.c.d, a.b.d, b.d}, {a, a.c, a.c.d} >  (False in a.c)
#       |(A \wedge B)|-alternatives to a.c = {b.d}
#         |C| = < {a.c, a.c.d, a.d}, {b.d} >  (False in b.d)
#
# Total Run Time: 0.2328 seconds
#
# ========================================

# %% [markdown]
# ### CF_CM_2: Might Counterfactual Antecedent Strengthening

# %%
run_example(counterfactual.CF_CM_2_example, "Might Counterfactual Antecedent Strengthening")
# Out:
# ========================================
#
# EXAMPLE Might Counterfactual Antecedent Strengthening: there is a countermodel.
#
# Atomic States: 3
#
# Semantic Theory: Default Semantics
#
# Premises:
# 1. \neg A
# 2. (A \diamondright C)
#
# Conclusion:
# 3. ((A \wedge B) \diamondright C)
#
# Z3 Run Time: 0.0046 seconds
#
# ========================================
# State Space:
#   #b000 = □
#   #b001 = a (world)
#   #b010 = b (world)
#   #b011 = a.b (impossible)
#   #b100 = c (impossible)
#   #b101 = a.c (impossible)
#   #b110 = b.c (impossible)
#   #b111 = a.b.c (impossible)
#
# The evaluation world is: b
#
# INTERPRETED PREMISES:
#
# 1.  |\neg A| = < {b}, {a} >  (True in b)
#       |A| = < {a}, {b} >  (False in b)
#
# 2.  |(A \diamondright C)| = < {□}, ∅ >  (True in b)
#       |A| = < {a}, {b} >  (False in b)
#       |A|-alternatives to b = {a}
#         |C| = < {a}, {b} >  (True in a)
#
# INTERPRETED CONCLUSION:
#
# 3.  |((A \wedge B) \diamondright C)| = < ∅, {□} >  (False in b)
#       |(A \wedge B)| = < {a.b}, {a, a.b, b} >  (False in b)
#         |A| = < {a}, {b} >  (False in b)
#         |B| = < {b}, {a} >  (True in b)
#       |(A \wedge B)|-alternatives to b = ∅
#
# Total Run Time: 0.0931 seconds
#
# ========================================

# %% [markdown]
# ### CF_CM_3: Counterfactual Antecedent Strengthening with Possibility

# %%
run_example(counterfactual.CF_CM_3_example, "Counterfactual Antecedent Strengthening with Possibility")
# Out:
# ========================================
#
# EXAMPLE Counterfactual Antecedent Strengthening with Possibility: there is a countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
# Premises:
# 1. \neg A
# 2. (A \boxright C)
# 3. \Diamond (A \wedge B)
#
# Conclusion:
# 4. ((A \wedge B) \boxright C)
#
# Z3 Run Time: 0.0291 seconds
#
# ========================================
# State Space:
#   #b0000 = □
#   #b0001 = a
#   #b0010 = b
#   #b0011 = a.b (impossible)
#   #b0100 = c
#   #b0101 = a.c (world)
#   #b0110 = b.c (world)
#   #b0111 = a.b.c (impossible)
#   #b1000 = d
#   #b1001 = a.d (impossible)
#   #b1010 = b.d (world)
#   #b1011 = a.b.d (impossible)
#   #b1100 = c.d (impossible)
#   #b1101 = a.c.d (impossible)
#   #b1110 = b.c.d (impossible)
#   #b1111 = a.b.c.d (impossible)
#
# The evaluation world is: a.c
#
# INTERPRETED PREMISES:
#
# 1.  |\neg A| = < {a.c, a.c.d}, {a.b.c.d, b} >  (True in a.c)
#       |A| = < {a.b.c.d, b}, {a.c, a.c.d} >  (False in a.c)
#
# 2.  |(A \boxright C)| = < {□}, ∅ >  (True in a.c)
#       |A| = < {a.b.c.d, b}, {a.c, a.c.d} >  (False in a.c)
#       |A|-alternatives to a.c = {b.c}
#         |C| = < {a.b.c, a.c, b.c}, {a.b.c.d, b.d} >  (True in b.c)
#
# 3.  |\Diamond (A \wedge B)| = < {□}, ∅ >  (True in a.c)
#       |(A \wedge B)| = < {a.b, a.b.c.d, a.b.d, b.c.d, b.d}, {a.b.c, a.b.c.d, a.c, a.c.d, b.c} >  (False in a.c)
#         |A| = < {a.b.c.d, b}, {a.c, a.c.d} >  (False in a.c)
#         |B| = < {a, a.b, a.b.c.d, a.b.d, a.c.d, b.c.d, b.d}, {b.c} >  (True in a.c)
#       |(A \wedge B)| = < {a.b, a.b.c.d, a.b.d, b.c.d, b.d}, {a.b.c, a.b.c.d, a.c, a.c.d, b.c} >  (False in b.c)
#         |A| = < {a.b.c.d, b}, {a.c, a.c.d} >  (True in b.c)
#         |B| = < {a, a.b, a.b.c.d, a.b.d, a.c.d, b.c.d, b.d}, {b.c} >  (False in b.c)
#       |(A \wedge B)| = < {a.b, a.b.c.d, a.b.d, b.c.d, b.d}, {a.b.c, a.b.c.d, a.c, a.c.d, b.c} >  (True in b.d)
#         |A| = < {a.b.c.d, b}, {a.c, a.c.d} >  (True in b.d)
#         |B| = < {a, a.b, a.b.c.d, a.b.d, a.c.d, b.c.d, b.d}, {b.c} >  (True in b.d)
#
# INTERPRETED CONCLUSION:
#
# 4.  |((A \wedge B) \boxright C)| = < ∅, {□} >  (False in a.c)
#       |(A \wedge B)| = < {a.b, a.b.c.d, a.b.d, b.c.d, b.d}, {a.b.c, a.b.c.d, a.c, a.c.d, b.c} >  (False in a.c)
#         |A| = < {a.b.c.d, b}, {a.c, a.c.d} >  (False in a.c)
#         |B| = < {a, a.b, a.b.c.d, a.b.d, a.c.d, b.c.d, b.d}, {b.c} >  (True in a.c)
#       |(A \wedge B)|-alternatives to a.c = {b.d}
#         |C| = < {a.b.c, a.c, b.c}, {a.b.c.d, b.d} >  (False in b.d)
#
# Total Run Time: 0.3069 seconds
#
# ========================================

# %% [markdown]
# ### CF_CM_4: Counterfactual Antecedent Strengthening with Negation

# %%
run_example(counterfactual.CF_CM_4_example, "Counterfactual Antecedent Strengthening with Negation")
# Out:
# ========================================
#
# EXAMPLE Counterfactual Antecedent Strengthening with Negation: there is a countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
# Premises:
# 1. \neg A
# 2. (A \boxright C)
#
# Conclusion:
# 3. ((A \wedge B) \boxright C)
#
# Z3 Run Time: 0.0149 seconds
#
# ========================================
# State Space:
#   #b0000 = □
#   #b0001 = a
#   #b0010 = b
#   #b0011 = a.b (impossible)
#   #b0100 = c
#   #b0101 = a.c (world)
#   #b0110 = b.c (impossible)
#   #b0111 = a.b.c (impossible)
#   #b1000 = d
#   #b1001 = a.d (impossible)
#   #b1010 = b.d (world)
#   #b1011 = a.b.d (impossible)
#   #b1100 = c.d (world)
#   #b1101 = a.c.d (impossible)
#   #b1110 = b.c.d (impossible)
#   #b1111 = a.b.c.d (impossible)
#
# The evaluation world is: b.d
#
# INTERPRETED PREMISES:
#
# 1.  |\neg A| = < {a.b.d, b.d}, {a.b.c, a.b.c.d, a.b.d, a.c.d, c} >  (True in b.d)
#       |A| = < {a.b.c, a.b.c.d, a.b.d, a.c.d, c}, {a.b.d, b.d} >  (False in b.d)
#
# 2.  |(A \boxright C)| = < {□}, ∅ >  (True in b.d)
#       |A| = < {a.b.c, a.b.c.d, a.b.d, a.c.d, c}, {a.b.d, b.d} >  (False in b.d)
#       |A|-alternatives to b.d = {c.d}
#         |C| = < {c.d}, {a.b.c.d, a.c, b.d} >  (True in c.d)
#
# INTERPRETED CONCLUSION:
#
# 3.  |((A \wedge B) \boxright C)| = < ∅, {□} >  (False in b.d)
#       |(A \wedge B)| = < {a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c, b.c.d}, {a.b.c.d, a.b.d, b.c.d, b.d, c.d} >  (False in b.d)
#         |A| = < {a.b.c, a.b.c.d, a.b.d, a.c.d, c}, {a.b.d, b.d} >  (False in b.d)
#         |B| = < {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c.d, b, b.c.d, b.d}, {c.d} >  (True in b.d)
#       |(A \wedge B)|-alternatives to b.d = {a.c}
#         |C| = < {c.d}, {a.b.c.d, a.c, b.d} >  (False in a.c)
#
# Total Run Time: 0.2869 seconds
#
# ========================================

# %% [markdown]
# ### CF_CM_5: Counterfactual Double Antecedent Strengthening

# %%
run_example(counterfactual.CF_CM_5_example, "Counterfactual Double Antecedent Strengthening")
# Out:
# ========================================
#
# EXAMPLE Counterfactual Double Antecedent Strengthening: there is a countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
# Premises:
# 1. (A \boxright C)
# 2. (B \boxright C)
#
# Conclusion:
# 3. ((A \wedge B) \boxright C)
#
# Z3 Run Time: 0.0147 seconds
#
# ========================================
# State Space:
#   #b0000 = □
#   #b0001 = a
#   #b0010 = b
#   #b0011 = a.b (impossible)
#   #b0100 = c
#   #b0101 = a.c (world)
#   #b0110 = b.c (world)
#   #b0111 = a.b.c (impossible)
#   #b1000 = d
#   #b1001 = a.d (world)
#   #b1010 = b.d (impossible)
#   #b1011 = a.b.d (impossible)
#   #b1100 = c.d (world)
#   #b1101 = a.c.d (impossible)
#   #b1110 = b.c.d (impossible)
#   #b1111 = a.b.c.d (impossible)
#
# The evaluation world is: b.c
#
# INTERPRETED PREMISES:
#
# 1.  |(A \boxright C)| = < {□}, ∅ >  (True in b.c)
#       |A| = < {a, a.b, a.b.c, a.b.c.d, a.b.d, b}, {a.b.c.d, c.d} >  (True in b.c)
#       |A|-alternatives to b.c = {a.c, b.c}
#         |C| = < {a.b.c, a.b.c.d, a.c, a.c.d, b.c, b.c.d, c.d}, {a.d} >  (True in b.c)
#         |C| = < {a.b.c, a.b.c.d, a.c, a.c.d, b.c, b.c.d, c.d}, {a.d} >  (True in a.c)
#
# 2.  |(B \boxright C)| = < {□}, ∅ >  (True in b.c)
#       |B| = < {a.b.d, d}, {a.b.c, a.c, b} >  (False in b.c)
#       |B|-alternatives to b.c = {c.d}
#         |C| = < {a.b.c, a.b.c.d, a.c, a.c.d, b.c, b.c.d, c.d}, {a.d} >  (True in c.d)
#
# INTERPRETED CONCLUSION:
#
# 3.  |((A \wedge B) \boxright C)| = < ∅, {□} >  (False in b.c)
#       |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b.c, a.b.c.d, a.c, a.c.d, b, b.c.d, c.d} >  (False in b.c)
#         |A| = < {a, a.b, a.b.c, a.b.c.d, a.b.d, b}, {a.b.c.d, c.d} >  (True in b.c)
#         |B| = < {a.b.d, d}, {a.b.c, a.c, b} >  (False in b.c)
#       |(A \wedge B)|-alternatives to b.c = {a.d}
#         |C| = < {a.b.c, a.b.c.d, a.c, a.c.d, b.c, b.c.d, c.d}, {a.d} >  (False in a.d)
#
# Total Run Time: 0.3554 seconds
#
# ========================================

# %% [markdown]
# ### CF_CM_6: Weakened Monotonicity

# %%
run_example(counterfactual.CF_CM_6_example, "Weakened Monotonicity")
# Out:
# ========================================
#
# EXAMPLE Weakened Monotonicity: there is a countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
# Premises:
# 1. \neg A
# 2. (A \boxright B)
# 3. (A \boxright C)
#
# Conclusion:
# 4. ((A \wedge B) \boxright C)
#
# Z3 Run Time: 0.021 seconds
#
# ========================================
# State Space:
#   #b0000 = □
#   #b0001 = a
#   #b0010 = b
#   #b0011 = a.b (impossible)
#   #b0100 = c
#   #b0101 = a.c (world)
#   #b0110 = b.c (world)
#   #b0111 = a.b.c (impossible)
#   #b1000 = d
#   #b1001 = a.d (world)
#   #b1010 = b.d (impossible)
#   #b1011 = a.b.d (impossible)
#   #b1100 = c.d (impossible)
#   #b1101 = a.c.d (impossible)
#   #b1110 = b.c.d (impossible)
#   #b1111 = a.b.c.d (impossible)
#
# The evaluation world is: a.d
#
# INTERPRETED PREMISES:
#
# 1.  |\neg A| = < {a.d}, {c} >  (True in a.d)
#       |A| = < {c}, {a.d} >  (False in a.d)
#
# 2.  |(A \boxright B)| = < {□}, ∅ >  (True in a.d)
#       |A| = < {c}, {a.d} >  (False in a.d)
#       |A|-alternatives to a.d = {a.c}
#         |B| = < {a.b.c, a.b.c.d, a.c, a.c.d, b, b.c}, {d} >  (True in a.c)
#
# 3.  |(A \boxright C)| = < {□}, ∅ >  (True in a.d)
#       |A| = < {c}, {a.d} >  (False in a.d)
#       |A|-alternatives to a.d = {a.c}
#         |C| = < {a, a.d}, {b.c} >  (True in a.c)
#
# INTERPRETED CONCLUSION:
#
# 4.  |((A \wedge B) \boxright C)| = < ∅, {□} >  (False in a.d)
#       |(A \wedge B)| = < {a.b.c, a.b.c.d, a.c, a.c.d, b.c}, {a.d, d} >  (False in a.d)
#         |A| = < {c}, {a.d} >  (False in a.d)
#         |B| = < {a.b.c, a.b.c.d, a.c, a.c.d, b, b.c}, {d} >  (False in a.d)
#       |(A \wedge B)|-alternatives to a.d = {a.c, b.c}
#         |C| = < {a, a.d}, {b.c} >  (False in b.c)
#         |C| = < {a, a.d}, {b.c} >  (True in a.c)
#
# Total Run Time: 0.2865 seconds
#
# ========================================

# %% [markdown]
# ### CF_CM_7: Counterfactual Contraposition

# %%
run_example(counterfactual.CF_CM_7_example, "Counterfactual Contraposition")
# Out:
# ========================================
#
# EXAMPLE Counterfactual Contraposition: there is a countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
# Premise:
# 1. (A \boxright B)
#
# Conclusion:
# 2. (\neg B \boxright \neg A)
#
# Z3 Run Time: 0.0091 seconds
#
# ========================================
# State Space:
#   #b0000 = □
#   #b0001 = a
#   #b0010 = b
#   #b0011 = a.b
#   #b0100 = c
#   #b0101 = a.c
#   #b0110 = b.c
#   #b0111 = a.b.c (world)
#   #b1000 = d
#   #b1001 = a.d
#   #b1010 = b.d
#   #b1011 = a.b.d (world)
#   #b1100 = c.d
#   #b1101 = a.c.d (world)
#   #b1110 = b.c.d (world)
#   #b1111 = a.b.c.d (impossible)
#
# The evaluation world is: a.b.c
#
# INTERPRETED PREMISE:
#
# 1.  |(A \boxright B)| = < {□}, ∅ >  (True in a.b.c)
#       |A| = < {a.b, a.b.c, b.c}, {a.c.d} >  (True in a.b.c)
#       |A|-alternatives to a.b.c = {a.b.c}
#         |B| = < {a.b.c}, {a.b.c.d, a.b.d, a.c.d, b.c.d, d} >  (True in a.b.c)
#
# INTERPRETED CONCLUSION:
#
# 2.  |(\neg B \boxright \neg A)| = < ∅, {□} >  (False in a.b.c)
#       |\neg B| = < {a.b.c.d, a.b.d, a.c.d, b.c.d, d}, {a.b.c} >  (False in a.b.c)
#         |B| = < {a.b.c}, {a.b.c.d, a.b.d, a.c.d, b.c.d, d} >  (True in a.b.c)
#       |\neg B|-alternatives to a.b.c = {a.b.d, a.c.d, b.c.d}
#         |\neg A| = < {a.c.d}, {a.b, a.b.c, b.c} >  (False in a.b.d)
#           |A| = < {a.b, a.b.c, b.c}, {a.c.d} >  (True in a.b.d)
#         |\neg A| = < {a.c.d}, {a.b, a.b.c, b.c} >  (True in a.c.d)
#           |A| = < {a.b, a.b.c, b.c}, {a.c.d} >  (False in a.c.d)
#         |\neg A| = < {a.c.d}, {a.b, a.b.c, b.c} >  (False in b.c.d)
#           |A| = < {a.b, a.b.c, b.c}, {a.c.d} >  (True in b.c.d)
#
# Total Run Time: 0.2501 seconds
#
# ========================================

# %% [markdown]
# ### CF_CM_8: Counterfactual Contraposition with Negation

# %%
run_example(counterfactual.CF_CM_8_example, "Counterfactual Contraposition with Negation")
# Out:
# ========================================
#
# EXAMPLE Counterfactual Contraposition with Negation: there is a countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
# Premises:
# 1. \neg B
# 2. (A \boxright B)
#
# Conclusion:
# 3. (\neg B \boxright \neg A)
#
# Z3 Run Time: 0.0103 seconds
#
# ========================================
# State Space:
#   #b0000 = □
#   #b0001 = a
#   #b0010 = b
#   #b0011 = a.b (world)
#   #b0100 = c
#   #b0101 = a.c (impossible)
#   #b0110 = b.c (impossible)
#   #b0111 = a.b.c (impossible)
#   #b1000 = d
#   #b1001 = a.d (impossible)
#   #b1010 = b.d (world)
#   #b1011 = a.b.d (impossible)
#   #b1100 = c.d (world)
#   #b1101 = a.c.d (impossible)
#   #b1110 = b.c.d (impossible)
#   #b1111 = a.b.c.d (impossible)
#
# The evaluation world is: a.b
#
# INTERPRETED PREMISES:
#
# 1.  |\neg B| = < {a, a.b.c.d, a.c.d, c.d}, {b.d} >  (True in a.b)
#       |B| = < {b.d}, {a, a.b.c.d, a.c.d, c.d} >  (False in a.b)
#
# 2.  |(A \boxright B)| = < {□}, ∅ >  (True in a.b)
#       |A| = < {d}, {a} >  (False in a.b)
#       |A|-alternatives to a.b = {b.d}
#         |B| = < {b.d}, {a, a.b.c.d, a.c.d, c.d} >  (True in b.d)
#
# INTERPRETED CONCLUSION:
#
# 3.  |(\neg B \boxright \neg A)| = < ∅, {□} >  (False in a.b)
#       |\neg B| = < {a, a.b.c.d, a.c.d, c.d}, {b.d} >  (True in a.b)
#         |B| = < {b.d}, {a, a.b.c.d, a.c.d, c.d} >  (False in a.b)
#       |\neg B|-alternatives to a.b = {a.b, c.d}
#         |\neg A| = < {a}, {d} >  (True in a.b)
#           |A| = < {d}, {a} >  (False in a.b)
#         |\neg A| = < {a}, {d} >  (False in c.d)
#           |A| = < {d}, {a} >  (True in c.d)
#
# Total Run Time: 0.1955 seconds
#
# ========================================

# %% [markdown]
# ### CF_CM_9: Counterfactual Contraposition with Two Negations

# %%
run_example(counterfactual.CF_CM_9_example, "Counterfactual Contraposition with Two Negations")
# Out:
# ========================================
#
# EXAMPLE Counterfactual Contraposition with Two Negations: there is a countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
# Premises:
# 1. \neg A
# 2. \neg B
# 3. (A \boxright B)
#
# Conclusion:
# 4. (\neg B \boxright \neg A)
#
# Z3 Run Time: 0.0104 seconds
#
# ========================================
# State Space:
#   #b0000 = □
#   #b0001 = a
#   #b0010 = b
#   #b0011 = a.b (impossible)
#   #b0100 = c
#   #b0101 = a.c (world)
#   #b0110 = b.c (impossible)
#   #b0111 = a.b.c (impossible)
#   #b1000 = d
#   #b1001 = a.d (world)
#   #b1010 = b.d (world)
#   #b1011 = a.b.d (impossible)
#   #b1100 = c.d (impossible)
#   #b1101 = a.c.d (impossible)
#   #b1110 = b.c.d (impossible)
#   #b1111 = a.b.c.d (impossible)
#
# The evaluation world is: a.c
#
# INTERPRETED PREMISES:
#
# 1.  |\neg A| = < {c}, {d} >  (True in a.c)
#       |A| = < {d}, {c} >  (False in a.c)
#
# 2.  |\neg B| = < {a.b.c, a.b.c.d, a.c, b, b.c, b.c.d}, {a.c.d, a.d} >  (True in a.c)
#       |B| = < {a.c.d, a.d}, {a.b.c, a.b.c.d, a.c, b, b.c, b.c.d} >  (False in a.c)
#
# 3.  |(A \boxright B)| = < {□}, ∅ >  (True in a.c)
#       |A| = < {d}, {c} >  (False in a.c)
#       |A|-alternatives to a.c = {a.d}
#         |B| = < {a.c.d, a.d}, {a.b.c, a.b.c.d, a.c, b, b.c, b.c.d} >  (True in a.d)
#
# INTERPRETED CONCLUSION:
#
# 4.  |(\neg B \boxright \neg A)| = < ∅, {□} >  (False in a.c)
#       |\neg B| = < {a.b.c, a.b.c.d, a.c, b, b.c, b.c.d}, {a.c.d, a.d} >  (True in a.c)
#         |B| = < {a.c.d, a.d}, {a.b.c, a.b.c.d, a.c, b, b.c, b.c.d} >  (False in a.c)
#       |\neg B|-alternatives to a.c = {a.c, b.d}
#         |\neg A| = < {c}, {d} >  (False in b.d)
#           |A| = < {d}, {c} >  (True in b.d)
#         |\neg A| = < {c}, {d} >  (True in a.c)
#           |A| = < {d}, {c} >  (False in a.c)
#
# Total Run Time: 0.223 seconds
#
# ========================================

# %% [markdown]
# ### CF_CM_10: Transitivity

# %%
run_example(counterfactual.CF_CM_10_example, "Transitivity")
# Out:
# ========================================
#
# EXAMPLE Transitivity: there is a countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
# Premises:
# 1. (A \boxright B)
# 2. (B \boxright C)
#
# Conclusion:
# 3. (A \boxright C)
#
# Z3 Run Time: 0.0137 seconds
#
# ========================================
# State Space:
#   #b0000 = □
#   #b0001 = a
#   #b0010 = b
#   #b0011 = a.b (world)
#   #b0100 = c
#   #b0101 = a.c (impossible)
#   #b0110 = b.c
#   #b0111 = a.b.c (impossible)
#   #b1000 = d
#   #b1001 = a.d (world)
#   #b1010 = b.d
#   #b1011 = a.b.d (impossible)
#   #b1100 = c.d
#   #b1101 = a.c.d (impossible)
#   #b1110 = b.c.d (world)
#   #b1111 = a.b.c.d (impossible)
#
# The evaluation world is: a.b
#
# INTERPRETED PREMISES:
#
# 1.  |(A \boxright B)| = < {□}, ∅ >  (True in a.b)
#       |A| = < {a.b, a.b.c, a.b.c.d, a.b.d, b.c.d, c}, {a.d} >  (True in a.b)
#       |A|-alternatives to a.b = {a.b, b.c.d}
#         |B| = < {b}, {a.d} >  (True in a.b)
#         |B| = < {b}, {a.d} >  (True in b.c.d)
#
# 2.  |(B \boxright C)| = < {□}, ∅ >  (True in a.b)
#       |B| = < {b}, {a.d} >  (True in a.b)
#       |B|-alternatives to a.b = {a.b}
#         |C| = < {a.b, a.b.c, a.b.c.d, a.b.d, a.c.d, a.d}, {a.b.c.d, b.c} >  (True in a.b)
#
# INTERPRETED CONCLUSION:
#
# 3.  |(A \boxright C)| = < ∅, {□} >  (False in a.b)
#       |A| = < {a.b, a.b.c, a.b.c.d, a.b.d, b.c.d, c}, {a.d} >  (True in a.b)
#       |A|-alternatives to a.b = {a.b, b.c.d}
#         |C| = < {a.b, a.b.c, a.b.c.d, a.b.d, a.c.d, a.d}, {a.b.c.d, b.c} >  (True in a.b)
#         |C| = < {a.b, a.b.c, a.b.c.d, a.b.d, a.c.d, a.d}, {a.b.c.d, b.c} >  (False in b.c.d)
#
# Total Run Time: 0.306 seconds
#
# ========================================

# %% [markdown]
# ### CF_CM_11: Counterfactual Transitivity with Negation

# %%
run_example(counterfactual.CF_CM_11_example, "Counterfactual Transitivity with Negation")
# Out:
# ========================================
#
# EXAMPLE Counterfactual Transitivity with Negation: there is a countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
# Premises:
# 1. \neg A
# 2. (A \boxright B)
# 3. (B \boxright C)
#
# Conclusion:
# 4. (A \boxright C)
#
# Z3 Run Time: 0.0131 seconds
#
# ========================================
# State Space:
#   #b0000 = □
#   #b0001 = a
#   #b0010 = b
#   #b0011 = a.b (world)
#   #b0100 = c
#   #b0101 = a.c (world)
#   #b0110 = b.c (world)
#   #b0111 = a.b.c (impossible)
#   #b1000 = d
#   #b1001 = a.d (world)
#   #b1010 = b.d (world)
#   #b1011 = a.b.d (impossible)
#   #b1100 = c.d (impossible)
#   #b1101 = a.c.d (impossible)
#   #b1110 = b.c.d (impossible)
#   #b1111 = a.b.c.d (impossible)
#
# The evaluation world is: b.c
#
# INTERPRETED PREMISES:
#
# 1.  |\neg A| = < {a.b.c.d, b}, {a.c, a.c.d, a.d} >  (True in b.c)
#       |A| = < {a.c, a.c.d, a.d}, {a.b.c.d, b} >  (False in b.c)
#
# 2.  |(A \boxright B)| = < {□}, ∅ >  (True in b.c)
#       |A| = < {a.c, a.c.d, a.d}, {a.b.c.d, b} >  (False in b.c)
#       |A|-alternatives to b.c = {a.c, a.d}
#         |B| = < {b.c.d, c, c.d, d}, {a.b} >  (True in a.d)
#         |B| = < {b.c.d, c, c.d, d}, {a.b} >  (True in a.c)
#
# 3.  |(B \boxright C)| = < {□}, ∅ >  (True in b.c)
#       |B| = < {b.c.d, c, c.d, d}, {a.b} >  (True in b.c)
#       |B|-alternatives to b.c = {b.c, b.d}
#         |C| = < {a.b, a.b.c, a.b.c.d, a.b.d, a.c, b.c, b.c.d, b.d}, {a.d} >  (True in b.c)
#         |C| = < {a.b, a.b.c, a.b.c.d, a.b.d, a.c, b.c, b.c.d, b.d}, {a.d} >  (True in b.d)
#
# INTERPRETED CONCLUSION:
#
# 4.  |(A \boxright C)| = < ∅, {□} >  (False in b.c)
#       |A| = < {a.c, a.c.d, a.d}, {a.b.c.d, b} >  (False in b.c)
#       |A|-alternatives to b.c = {a.c, a.d}
#         |C| = < {a.b, a.b.c, a.b.c.d, a.b.d, a.c, b.c, b.c.d, b.d}, {a.d} >  (False in a.d)
#         |C| = < {a.b, a.b.c, a.b.c.d, a.b.d, a.c, b.c, b.c.d, b.d}, {a.d} >  (True in a.c)
#
# Total Run Time: 0.3405 seconds
#
# ========================================

# %% [markdown]
# ### CF_CM_12: Counterfactual Transitivity with Two Negations

# %%
run_example(counterfactual.CF_CM_12_example, "Counterfactual Transitivity with Two Negations")
# Out:
# ========================================
#
# EXAMPLE Counterfactual Transitivity with Two Negations: there is a countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
# Premises:
# 1. \neg A
# 2. \neg B
# 3. (A \boxright B)
# 4. (B \boxright C)
#
# Conclusion:
# 5. (A \boxright C)
#
# Z3 Run Time: 0.0382 seconds
#
# ========================================
# State Space:
#   #b0000 = □
#   #b0001 = a
#   #b0010 = b
#   #b0011 = a.b (world)
#   #b0100 = c
#   #b0101 = a.c (world)
#   #b0110 = b.c (impossible)
#   #b0111 = a.b.c (impossible)
#   #b1000 = d
#   #b1001 = a.d (world)
#   #b1010 = b.d (impossible)
#   #b1011 = a.b.d (impossible)
#   #b1100 = c.d (world)
#   #b1101 = a.c.d (impossible)
#   #b1110 = b.c.d (impossible)
#   #b1111 = a.b.c.d (impossible)
#
# The evaluation world is: a.b
#
# INTERPRETED PREMISES:
#
# 1.  |\neg A| = < {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c.d}, {c.d} >  (True in a.b)
#       |A| = < {c.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c.d} >  (False in a.b)
#
# 2.  |\neg B| = < {a.b.c, a.b.c.d, a.c, b}, {d} >  (True in a.b)
#       |B| = < {d}, {a.b.c, a.b.c.d, a.c, b} >  (False in a.b)
#
# 3.  |(A \boxright B)| = < {□}, ∅ >  (True in a.b)
#       |A| = < {c.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c.d} >  (False in a.b)
#       |A|-alternatives to a.b = {c.d}
#         |B| = < {d}, {a.b.c, a.b.c.d, a.c, b} >  (True in c.d)
#
# 4.  |(B \boxright C)| = < {□}, ∅ >  (True in a.b)
#       |B| = < {d}, {a.b.c, a.b.c.d, a.c, b} >  (False in a.b)
#       |B|-alternatives to a.b = {a.d}
#         |C| = < {a}, {c.d} >  (True in a.d)
#
# INTERPRETED CONCLUSION:
#
# 5.  |(A \boxright C)| = < ∅, {□} >  (False in a.b)
#       |A| = < {c.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c.d} >  (False in a.b)
#       |A|-alternatives to a.b = {c.d}
#         |C| = < {a}, {c.d} >  (False in c.d)
#
# Total Run Time: 0.2838 seconds
#
# ========================================

# %% [markdown]
# ### CF_CM_13: Sobel Sequence

# %%
run_example(counterfactual.CF_CM_13_example, "Sobel Sequence")
# Out:
# ========================================
#
# EXAMPLE Sobel Sequence: there is a countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
#
# Z3 Run Time: 0.0541 seconds
#
# ========================================
# State Space:
#   #b0000 = □
#   #b0001 = a (impossible)
#   #b0010 = b
#   #b0011 = a.b (impossible)
#   #b0100 = c
#   #b0101 = a.c (impossible)
#   #b0110 = b.c (world)
#   #b0111 = a.b.c (impossible)
#   #b1000 = d
#   #b1001 = a.d (impossible)
#   #b1010 = b.d (world)
#   #b1011 = a.b.d (impossible)
#   #b1100 = c.d (world)
#   #b1101 = a.c.d (impossible)
#   #b1110 = b.c.d (impossible)
#   #b1111 = a.b.c.d (impossible)
#
# The evaluation world is: b.d
#
# INTERPRETED PREMISES:
#
# 1.  |(A \boxright X)| = < {□}, ∅ >  (True in b.d)
#       |A| = < {a.b.c, a.b.c.d, a.b.d, a.c.d, a.d, d}, {b.c} >  (True in b.d)
#       |A|-alternatives to b.d = {b.d}
#         |X| = < {b.d}, {b.c, b.c.d, c.d} >  (True in b.d)
#
# 2.  |\neg ((A \wedge B) \boxright X)| = < {□}, ∅ >  (True in b.d)
#       |((A \wedge B) \boxright X)| = < ∅, {□} >  (False in b.d)
#         |(A \wedge B)| = < {a.b.c, a.b.c.d, a.b.d, a.c.d, b.c.d, c.d}, {b.c, b.c.d, b.d} >  (False in b.d)
#           |A| = < {a.b.c, a.b.c.d, a.b.d, a.c.d, a.d, d}, {b.c} >  (True in b.d)
#           |B| = < {a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c}, {b.d} >  (False in b.d)
#           |(A \wedge B)|-alternatives to b.d = {c.d}
#             |X| = < {b.d}, {b.c, b.c.d, c.d} >  (False in c.d)
#
# 3.  |(((A \wedge B) \wedge C) \boxright X)| = < {□}, ∅ >  (True in b.d)
#       |((A \wedge B) \wedge C)| = < {a.b.c, a.b.c.d, a.b.d, a.c.d, b.c.d}, {b.c, b.c.d, b.d, c.d} >  (False in b.d)
#         |(A \wedge B)| = < {a.b.c, a.b.c.d, a.b.d, a.c.d, b.c.d, c.d}, {b.c, b.c.d, b.d} >  (False in b.d)
#           |A| = < {a.b.c, a.b.c.d, a.b.d, a.c.d, a.d, d}, {b.c} >  (True in b.d)
#           |B| = < {a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c}, {b.d} >  (False in b.d)
#         |C| = < {a.b.c, a.b.c.d, a.c, b.d}, {b.c, b.c.d, c.d} >  (True in b.d)
#       |((A \wedge B) \wedge C)|-alternatives to b.d = ∅
#
# 4.  |\neg ((((A \wedge B) \wedge C) \wedge D) \boxright X)| = < {□}, ∅ >  (True in b.d)
#       |((((A \wedge B) \wedge C) \wedge D) \boxright X)| = < ∅, {□} >  (False in b.d)
#         |(((A \wedge B) \wedge C) \wedge D)| = < {a.b.c.d, a.c.d, b.c.d}, {b, b.c, b.c.d, b.d, c.d} >  (False in b.d)
#           |((A \wedge B) \wedge C)| = < {a.b.c, a.b.c.d, a.b.d, a.c.d, b.c.d}, {b.c, b.c.d, b.d, c.d} >  (False in b.d)
#             |(A \wedge B)| = < {a.b.c, a.b.c.d, a.b.d, a.c.d, b.c.d, c.d}, {b.c, b.c.d, b.d} >  (False in b.d)
#               |A| = < {a.b.c, a.b.c.d, a.b.d, a.c.d, a.d, d}, {b.c} >  (True in b.d)
#               |B| = < {a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c}, {b.d} >  (False in b.d)
#             |C| = < {a.b.c, a.b.c.d, a.c, b.d}, {b.c, b.c.d, c.d} >  (True in b.d)
#           |D| = < {c.d}, {b, b.c.d} >  (False in b.d)
#           |(((A \wedge B) \wedge C) \wedge D)|-alternatives to b.d = ∅
#
# 5.  |(((((A \wedge B) \wedge C) \wedge D) \wedge E) \boxright X)| = < {□}, ∅ >  (True in b.d)
#       |((((A \wedge B) \wedge C) \wedge D) \wedge E)| = < {a.b.c.d, a.c.d, b.c.d}, {b, b.c, b.c.d, b.d, c, c.d} >  (False in b.d)
#         |(((A \wedge B) \wedge C) \wedge D)| = < {a.b.c.d, a.c.d, b.c.d}, {b, b.c, b.c.d, b.d, c.d} >  (False in b.d)
#           |((A \wedge B) \wedge C)| = < {a.b.c, a.b.c.d, a.b.d, a.c.d, b.c.d}, {b.c, b.c.d, b.d, c.d} >  (False in b.d)
#             |(A \wedge B)| = < {a.b.c, a.b.c.d, a.b.d, a.c.d, b.c.d, c.d}, {b.c, b.c.d, b.d} >  (False in b.d)
#               |A| = < {a.b.c, a.b.c.d, a.b.d, a.c.d, a.d, d}, {b.c} >  (True in b.d)
#               |B| = < {a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c}, {b.d} >  (False in b.d)
#             |C| = < {a.b.c, a.b.c.d, a.c, b.d}, {b.c, b.c.d, c.d} >  (True in b.d)
#           |D| = < {c.d}, {b, b.c.d} >  (False in b.d)
#         |E| = < {a.b.c, a.b.c.d, a.b.d, a.c.d, b.d}, {b.c.d, c} >  (True in b.d)
#       |((((A \wedge B) \wedge C) \wedge D) \wedge E)|-alternatives to b.d = ∅
#
# 6.  |\neg ((((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F) \boxright X)| = < {□}, ∅ >  (True in b.d)
#       |((((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F) \boxright X)| = < ∅, {□} >  (False in b.d)
#         |(((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F)| = < {a.b.c.d, a.c.d, b.c.d}, {b, b.c, b.c.d, b.d, c, c.d, d} >  (False in b.d)
#           |((((A \wedge B) \wedge C) \wedge D) \wedge E)| = < {a.b.c.d, a.c.d, b.c.d}, {b, b.c, b.c.d, b.d, c, c.d} >  (False in b.d)
#             |(((A \wedge B) \wedge C) \wedge D)| = < {a.b.c.d, a.c.d, b.c.d}, {b, b.c, b.c.d, b.d, c.d} >  (False in b.d)
#               |((A \wedge B) \wedge C)| = < {a.b.c, a.b.c.d, a.b.d, a.c.d, b.c.d}, {b.c, b.c.d, b.d, c.d} >  (False in b.d)
#                 |(A \wedge B)| = < {a.b.c, a.b.c.d, a.b.d, a.c.d, b.c.d, c.d}, {b.c, b.c.d, b.d} >  (False in b.d)
#                   |A| = < {a.b.c, a.b.c.d, a.b.d, a.c.d, a.d, d}, {b.c} >  (True in b.d)
#                   |B| = < {a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c}, {b.d} >  (False in b.d)
#                 |C| = < {a.b.c, a.b.c.d, a.c, b.d}, {b.c, b.c.d, c.d} >  (True in b.d)
#               |D| = < {c.d}, {b, b.c.d} >  (False in b.d)
#             |E| = < {a.b.c, a.b.c.d, a.b.d, a.c.d, b.d}, {b.c.d, c} >  (True in b.d)
#           |F| = < {a.b.c, a.b.c.d, a.b.d, a.c.d, b.c}, {d} >  (False in b.d)
#           |(((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F)|-alternatives to b.d = ∅
#
# 7.  |(((((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F) \wedge G) \boxright X)| = < {□}, ∅ >  (True in b.d)
#       |((((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F) \wedge G)| = < {a.b.c.d, a.c.d, b.c.d}, {b, b.c, b.c.d, b.d, c, c.d, d} >  (False in b.d)
#         |(((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F)| = < {a.b.c.d, a.c.d, b.c.d}, {b, b.c, b.c.d, b.d, c, c.d, d} >  (False in b.d)
#           |((((A \wedge B) \wedge C) \wedge D) \wedge E)| = < {a.b.c.d, a.c.d, b.c.d}, {b, b.c, b.c.d, b.d, c, c.d} >  (False in b.d)
#             |(((A \wedge B) \wedge C) \wedge D)| = < {a.b.c.d, a.c.d, b.c.d}, {b, b.c, b.c.d, b.d, c.d} >  (False in b.d)
#               |((A \wedge B) \wedge C)| = < {a.b.c, a.b.c.d, a.b.d, a.c.d, b.c.d}, {b.c, b.c.d, b.d, c.d} >  (False in b.d)
#                 |(A \wedge B)| = < {a.b.c, a.b.c.d, a.b.d, a.c.d, b.c.d, c.d}, {b.c, b.c.d, b.d} >  (False in b.d)
#                   |A| = < {a.b.c, a.b.c.d, a.b.d, a.c.d, a.d, d}, {b.c} >  (True in b.d)
#                   |B| = < {a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c}, {b.d} >  (False in b.d)
#                 |C| = < {a.b.c, a.b.c.d, a.c, b.d}, {b.c, b.c.d, c.d} >  (True in b.d)
#               |D| = < {c.d}, {b, b.c.d} >  (False in b.d)
#             |E| = < {a.b.c, a.b.c.d, a.b.d, a.c.d, b.d}, {b.c.d, c} >  (True in b.d)
#           |F| = < {a.b.c, a.b.c.d, a.b.d, a.c.d, b.c}, {d} >  (False in b.d)
#         |G| = < {a.b.c, a.b.c.d, a.b.d, a.c.d, b.d}, {b.c, b.c.d, c.d} >  (True in b.d)
#       |((((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F) \wedge G)|-alternatives to b.d = ∅
#
# Total Run Time: 1.2937 seconds
#
# ========================================

# %% [markdown]
# ### CF_CM_14: Sobel Sequence with Possibility

# %%
run_example(counterfactual.CF_CM_14_example, "Sobel Sequence with Possibility")
# Out:
# ========================================
#
# EXAMPLE Sobel Sequence with Possibility: there is a countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
#
# Z3 Run Time: 0.0405 seconds
#
# ========================================
# State Space:
#   #b0000 = □
#   #b0001 = a
#   #b0010 = b
#   #b0011 = a.b
#   #b0100 = c
#   #b0101 = a.c
#   #b0110 = b.c
#   #b0111 = a.b.c (world)
#   #b1000 = d
#   #b1001 = a.d (world)
#   #b1010 = b.d (world)
#   #b1011 = a.b.d (impossible)
#   #b1100 = c.d (world)
#   #b1101 = a.c.d (impossible)
#   #b1110 = b.c.d (impossible)
#   #b1111 = a.b.c.d (impossible)
#
# The evaluation world is: c.d
#
# INTERPRETED PREMISES:
#
# 1.  |\Diamond A| = < {□}, ∅ >  (True in c.d)
#       |A| = < {a.b.d, d}, {a.b, a.b.c} >  (False in a.b.c)
#       |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in a.d)
#       |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in b.d)
#       |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in c.d)
#
# 2.  |(A \boxright X)| = < {□}, ∅ >  (True in c.d)
#       |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in c.d)
#       |A|-alternatives to c.d = {c.d}
#         |X| = < {b.c.d, b.d, c.d}, {a.b.c, a.b.c.d, a.d} >  (True in c.d)
#
# 3.  |\Diamond (A \wedge B)| = < {□}, ∅ >  (True in c.d)
#       |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (False in a.b.c)
#         |A| = < {a.b.d, d}, {a.b, a.b.c} >  (False in a.b.c)
#         |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (True in a.b.c)
#       |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (True in a.d)
#         |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in a.d)
#         |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (True in a.d)
#       |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (True in b.d)
#         |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in b.d)
#         |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (True in b.d)
#       |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (False in c.d)
#         |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in c.d)
#         |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (False in c.d)
#
# 4.  |\neg ((A \wedge B) \boxright X)| = < {□}, ∅ >  (True in c.d)
#       |((A \wedge B) \boxright X)| = < ∅, {□} >  (False in c.d)
#         |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (False in c.d)
#           |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in c.d)
#           |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (False in c.d)
#           |(A \wedge B)|-alternatives to c.d = {a.d, b.d}
#             |X| = < {b.c.d, b.d, c.d}, {a.b.c, a.b.c.d, a.d} >  (True in b.d)
#             |X| = < {b.c.d, b.d, c.d}, {a.b.c, a.b.c.d, a.d} >  (False in a.d)
#
# 5.  |\Diamond ((A \wedge B) \wedge C)| = < {□}, ∅ >  (True in c.d)
#       |((A \wedge B) \wedge C)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in a.b.c)
#         |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (False in a.b.c)
#           |A| = < {a.b.d, d}, {a.b, a.b.c} >  (False in a.b.c)
#           |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (True in a.b.c)
#         |C| = < {a.b.c.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c} >  (False in a.b.c)
#       |((A \wedge B) \wedge C)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in a.d)
#         |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (True in a.d)
#           |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in a.d)
#           |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (True in a.d)
#         |C| = < {a.b.c.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c} >  (False in a.d)
#       |((A \wedge B) \wedge C)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (True in b.d)
#         |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (True in b.d)
#           |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in b.d)
#           |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (True in b.d)
#         |C| = < {a.b.c.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c} >  (True in b.d)
#       |((A \wedge B) \wedge C)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in c.d)
#         |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (False in c.d)
#           |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in c.d)
#           |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (False in c.d)
#         |C| = < {a.b.c.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c} >  (False in c.d)
#
# 6.  |(((A \wedge B) \wedge C) \boxright X)| = < {□}, ∅ >  (True in c.d)
#       |((A \wedge B) \wedge C)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in c.d)
#         |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (False in c.d)
#           |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in c.d)
#           |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (False in c.d)
#         |C| = < {a.b.c.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c} >  (False in c.d)
#       |((A \wedge B) \wedge C)|-alternatives to c.d = {b.d}
#         |X| = < {b.c.d, b.d, c.d}, {a.b.c, a.b.c.d, a.d} >  (True in b.d)
#
# 7.  |\Diamond (((A \wedge B) \wedge C) \wedge D)| = < {□}, ∅ >  (True in c.d)
#       |(((A \wedge B) \wedge C) \wedge D)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in a.b.c)
#         |((A \wedge B) \wedge C)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in a.b.c)
#           |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (False in a.b.c)
#             |A| = < {a.b.d, d}, {a.b, a.b.c} >  (False in a.b.c)
#             |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (True in a.b.c)
#           |C| = < {a.b.c.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c} >  (False in a.b.c)
#         |D| = < {a.b.d, a.d, b.d}, {a.c, a.c.d, c.d} >  (False in a.b.c)
#       |(((A \wedge B) \wedge C) \wedge D)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in a.d)
#         |((A \wedge B) \wedge C)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in a.d)
#           |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (True in a.d)
#             |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in a.d)
#             |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (True in a.d)
#           |C| = < {a.b.c.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c} >  (False in a.d)
#         |D| = < {a.b.d, a.d, b.d}, {a.c, a.c.d, c.d} >  (True in a.d)
#       |(((A \wedge B) \wedge C) \wedge D)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (True in b.d)
#         |((A \wedge B) \wedge C)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (True in b.d)
#           |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (True in b.d)
#             |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in b.d)
#             |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (True in b.d)
#           |C| = < {a.b.c.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c} >  (True in b.d)
#         |D| = < {a.b.d, a.d, b.d}, {a.c, a.c.d, c.d} >  (True in b.d)
#       |(((A \wedge B) \wedge C) \wedge D)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in c.d)
#         |((A \wedge B) \wedge C)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in c.d)
#           |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (False in c.d)
#             |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in c.d)
#             |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (False in c.d)
#           |C| = < {a.b.c.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c} >  (False in c.d)
#         |D| = < {a.b.d, a.d, b.d}, {a.c, a.c.d, c.d} >  (False in c.d)
#
# 8.  |\neg ((((A \wedge B) \wedge C) \wedge D) \boxright X)| = < {□}, ∅ >  (True in c.d)
#       |((((A \wedge B) \wedge C) \wedge D) \boxright X)| = < ∅, {□} >  (False in c.d)
#         |(((A \wedge B) \wedge C) \wedge D)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in c.d)
#           |((A \wedge B) \wedge C)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in c.d)
#             |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (False in c.d)
#               |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in c.d)
#               |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (False in c.d)
#             |C| = < {a.b.c.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c} >  (False in c.d)
#           |D| = < {a.b.d, a.d, b.d}, {a.c, a.c.d, c.d} >  (False in c.d)
#           |(((A \wedge B) \wedge C) \wedge D)|-alternatives to c.d = {b.d}
#             |X| = < {b.c.d, b.d, c.d}, {a.b.c, a.b.c.d, a.d} >  (True in b.d)
#
# 9.  |\Diamond ((((A \wedge B) \wedge C) \wedge D) \wedge E)| = < {□}, ∅ >  (True in c.d)
#       |((((A \wedge B) \wedge C) \wedge D) \wedge E)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (False in a.b.c)
#         |(((A \wedge B) \wedge C) \wedge D)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in a.b.c)
#           |((A \wedge B) \wedge C)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in a.b.c)
#             |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (False in a.b.c)
#               |A| = < {a.b.d, d}, {a.b, a.b.c} >  (False in a.b.c)
#               |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (True in a.b.c)
#             |C| = < {a.b.c.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c} >  (False in a.b.c)
#           |D| = < {a.b.d, a.d, b.d}, {a.c, a.c.d, c.d} >  (False in a.b.c)
#         |E| = < {a.b.c.d, b.d}, {a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c} >  (False in a.b.c)
#       |((((A \wedge B) \wedge C) \wedge D) \wedge E)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (False in a.d)
#         |(((A \wedge B) \wedge C) \wedge D)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in a.d)
#           |((A \wedge B) \wedge C)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in a.d)
#             |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (True in a.d)
#               |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in a.d)
#               |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (True in a.d)
#             |C| = < {a.b.c.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c} >  (False in a.d)
#           |D| = < {a.b.d, a.d, b.d}, {a.c, a.c.d, c.d} >  (True in a.d)
#         |E| = < {a.b.c.d, b.d}, {a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c} >  (False in a.d)
#       |((((A \wedge B) \wedge C) \wedge D) \wedge E)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (True in b.d)
#         |(((A \wedge B) \wedge C) \wedge D)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (True in b.d)
#           |((A \wedge B) \wedge C)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (True in b.d)
#             |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (True in b.d)
#               |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in b.d)
#               |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (True in b.d)
#             |C| = < {a.b.c.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c} >  (True in b.d)
#           |D| = < {a.b.d, a.d, b.d}, {a.c, a.c.d, c.d} >  (True in b.d)
#         |E| = < {a.b.c.d, b.d}, {a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c} >  (True in b.d)
#       |((((A \wedge B) \wedge C) \wedge D) \wedge E)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (False in c.d)
#         |(((A \wedge B) \wedge C) \wedge D)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in c.d)
#           |((A \wedge B) \wedge C)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in c.d)
#             |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (False in c.d)
#               |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in c.d)
#               |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (False in c.d)
#             |C| = < {a.b.c.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c} >  (False in c.d)
#           |D| = < {a.b.d, a.d, b.d}, {a.c, a.c.d, c.d} >  (False in c.d)
#         |E| = < {a.b.c.d, b.d}, {a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c} >  (False in c.d)
#
# 10.  |(((((A \wedge B) \wedge C) \wedge D) \wedge E) \boxright X)| = < {□}, ∅ >  (True in c.d)
#       |((((A \wedge B) \wedge C) \wedge D) \wedge E)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (False in c.d)
#         |(((A \wedge B) \wedge C) \wedge D)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in c.d)
#           |((A \wedge B) \wedge C)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in c.d)
#             |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (False in c.d)
#               |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in c.d)
#               |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (False in c.d)
#             |C| = < {a.b.c.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c} >  (False in c.d)
#           |D| = < {a.b.d, a.d, b.d}, {a.c, a.c.d, c.d} >  (False in c.d)
#         |E| = < {a.b.c.d, b.d}, {a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c} >  (False in c.d)
#       |((((A \wedge B) \wedge C) \wedge D) \wedge E)|-alternatives to c.d = {b.d}
#         |X| = < {b.c.d, b.d, c.d}, {a.b.c, a.b.c.d, a.d} >  (True in b.d)
#
# 11.  |\Diamond (((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F)| = < {□}, ∅ >  (True in c.d)
#       |(((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (False in a.b.c)
#         |((((A \wedge B) \wedge C) \wedge D) \wedge E)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (False in a.b.c)
#           |(((A \wedge B) \wedge C) \wedge D)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in a.b.c)
#             |((A \wedge B) \wedge C)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in a.b.c)
#               |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (False in a.b.c)
#                 |A| = < {a.b.d, d}, {a.b, a.b.c} >  (False in a.b.c)
#                 |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (True in a.b.c)
#               |C| = < {a.b.c.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c} >  (False in a.b.c)
#             |D| = < {a.b.d, a.d, b.d}, {a.c, a.c.d, c.d} >  (False in a.b.c)
#           |E| = < {a.b.c.d, b.d}, {a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c} >  (False in a.b.c)
#         |F| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.c, c} >  (False in a.b.c)
#       |(((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (False in a.d)
#         |((((A \wedge B) \wedge C) \wedge D) \wedge E)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (False in a.d)
#           |(((A \wedge B) \wedge C) \wedge D)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in a.d)
#             |((A \wedge B) \wedge C)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in a.d)
#               |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (True in a.d)
#                 |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in a.d)
#                 |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (True in a.d)
#               |C| = < {a.b.c.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c} >  (False in a.d)
#             |D| = < {a.b.d, a.d, b.d}, {a.c, a.c.d, c.d} >  (True in a.d)
#           |E| = < {a.b.c.d, b.d}, {a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c} >  (False in a.d)
#         |F| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.c, c} >  (True in a.d)
#       |(((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (True in b.d)
#         |((((A \wedge B) \wedge C) \wedge D) \wedge E)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (True in b.d)
#           |(((A \wedge B) \wedge C) \wedge D)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (True in b.d)
#             |((A \wedge B) \wedge C)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (True in b.d)
#               |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (True in b.d)
#                 |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in b.d)
#                 |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (True in b.d)
#               |C| = < {a.b.c.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c} >  (True in b.d)
#             |D| = < {a.b.d, a.d, b.d}, {a.c, a.c.d, c.d} >  (True in b.d)
#           |E| = < {a.b.c.d, b.d}, {a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c} >  (True in b.d)
#         |F| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.c, c} >  (True in b.d)
#       |(((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (False in c.d)
#         |((((A \wedge B) \wedge C) \wedge D) \wedge E)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (False in c.d)
#           |(((A \wedge B) \wedge C) \wedge D)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in c.d)
#             |((A \wedge B) \wedge C)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in c.d)
#               |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (False in c.d)
#                 |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in c.d)
#                 |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (False in c.d)
#               |C| = < {a.b.c.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c} >  (False in c.d)
#             |D| = < {a.b.d, a.d, b.d}, {a.c, a.c.d, c.d} >  (False in c.d)
#           |E| = < {a.b.c.d, b.d}, {a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c} >  (False in c.d)
#         |F| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.c, c} >  (False in c.d)
#
# 12.  |\neg ((((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F) \boxright X)| = < {□}, ∅ >  (True in c.d)
#       |((((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F) \boxright X)| = < ∅, {□} >  (False in c.d)
#         |(((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (False in c.d)
#           |((((A \wedge B) \wedge C) \wedge D) \wedge E)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (False in c.d)
#             |(((A \wedge B) \wedge C) \wedge D)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in c.d)
#               |((A \wedge B) \wedge C)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in c.d)
#                 |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (False in c.d)
#                   |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in c.d)
#                   |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (False in c.d)
#                 |C| = < {a.b.c.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c} >  (False in c.d)
#               |D| = < {a.b.d, a.d, b.d}, {a.c, a.c.d, c.d} >  (False in c.d)
#             |E| = < {a.b.c.d, b.d}, {a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c} >  (False in c.d)
#           |F| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.c, c} >  (False in c.d)
#           |(((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F)|-alternatives to c.d = {b.d}
#             |X| = < {b.c.d, b.d, c.d}, {a.b.c, a.b.c.d, a.d} >  (True in b.d)
#
# 13.  |\Diamond ((((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F) \wedge G)| = < {□}, ∅ >  (True in c.d)
#       |((((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F) \wedge G)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (False in a.b.c)
#         |(((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (False in a.b.c)
#           |((((A \wedge B) \wedge C) \wedge D) \wedge E)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (False in a.b.c)
#             |(((A \wedge B) \wedge C) \wedge D)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in a.b.c)
#               |((A \wedge B) \wedge C)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in a.b.c)
#                 |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (False in a.b.c)
#                   |A| = < {a.b.d, d}, {a.b, a.b.c} >  (False in a.b.c)
#                   |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (True in a.b.c)
#                 |C| = < {a.b.c.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c} >  (False in a.b.c)
#               |D| = < {a.b.d, a.d, b.d}, {a.c, a.c.d, c.d} >  (False in a.b.c)
#             |E| = < {a.b.c.d, b.d}, {a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c} >  (False in a.b.c)
#           |F| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.c, c} >  (False in a.b.c)
#         |G| = < {b.d}, {a.b.c.d, a.c.d, a.d, c} >  (False in a.b.c)
#       |((((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F) \wedge G)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (False in a.d)
#         |(((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (False in a.d)
#           |((((A \wedge B) \wedge C) \wedge D) \wedge E)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (False in a.d)
#             |(((A \wedge B) \wedge C) \wedge D)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in a.d)
#               |((A \wedge B) \wedge C)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in a.d)
#                 |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (True in a.d)
#                   |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in a.d)
#                   |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (True in a.d)
#                 |C| = < {a.b.c.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c} >  (False in a.d)
#               |D| = < {a.b.d, a.d, b.d}, {a.c, a.c.d, c.d} >  (True in a.d)
#             |E| = < {a.b.c.d, b.d}, {a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c} >  (False in a.d)
#           |F| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.c, c} >  (True in a.d)
#         |G| = < {b.d}, {a.b.c.d, a.c.d, a.d, c} >  (False in a.d)
#       |((((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F) \wedge G)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (True in b.d)
#         |(((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (True in b.d)
#           |((((A \wedge B) \wedge C) \wedge D) \wedge E)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (True in b.d)
#             |(((A \wedge B) \wedge C) \wedge D)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (True in b.d)
#               |((A \wedge B) \wedge C)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (True in b.d)
#                 |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (True in b.d)
#                   |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in b.d)
#                   |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (True in b.d)
#                 |C| = < {a.b.c.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c} >  (True in b.d)
#               |D| = < {a.b.d, a.d, b.d}, {a.c, a.c.d, c.d} >  (True in b.d)
#             |E| = < {a.b.c.d, b.d}, {a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c} >  (True in b.d)
#           |F| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.c, c} >  (True in b.d)
#         |G| = < {b.d}, {a.b.c.d, a.c.d, a.d, c} >  (True in b.d)
#       |((((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F) \wedge G)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (False in c.d)
#         |(((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (False in c.d)
#           |((((A \wedge B) \wedge C) \wedge D) \wedge E)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (False in c.d)
#             |(((A \wedge B) \wedge C) \wedge D)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in c.d)
#               |((A \wedge B) \wedge C)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in c.d)
#                 |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (False in c.d)
#                   |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in c.d)
#                   |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (False in c.d)
#                 |C| = < {a.b.c.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c} >  (False in c.d)
#               |D| = < {a.b.d, a.d, b.d}, {a.c, a.c.d, c.d} >  (False in c.d)
#             |E| = < {a.b.c.d, b.d}, {a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c} >  (False in c.d)
#           |F| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.c, c} >  (False in c.d)
#         |G| = < {b.d}, {a.b.c.d, a.c.d, a.d, c} >  (False in c.d)
#
# 14.  |(((((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F) \wedge G) \boxright X)| = < {□}, ∅ >  (True in c.d)
#       |((((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F) \wedge G)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (False in c.d)
#         |(((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (False in c.d)
#           |((((A \wedge B) \wedge C) \wedge D) \wedge E)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c, c.d} >  (False in c.d)
#             |(((A \wedge B) \wedge C) \wedge D)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in c.d)
#               |((A \wedge B) \wedge C)| = < {a.b.c.d, a.b.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c, c.d} >  (False in c.d)
#                 |(A \wedge B)| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.b.c.d, c.d} >  (False in c.d)
#                   |A| = < {a.b.d, d}, {a.b, a.b.c} >  (True in c.d)
#                   |B| = < {a, a.b.c, a.b.c.d, a.b.d, a.d, b.d}, {c.d} >  (False in c.d)
#                 |C| = < {a.b.c.d, b.d}, {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b.c.d, c} >  (False in c.d)
#               |D| = < {a.b.d, a.d, b.d}, {a.c, a.c.d, c.d} >  (False in c.d)
#             |E| = < {a.b.c.d, b.d}, {a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, a.d, b.c.d, c} >  (False in c.d)
#           |F| = < {a.b.c.d, a.b.d, a.d, b.d}, {a.b, a.b.c, a.c, c} >  (False in c.d)
#         |G| = < {b.d}, {a.b.c.d, a.c.d, a.d, c} >  (False in c.d)
#       |((((((A \wedge B) \wedge C) \wedge D) \wedge E) \wedge F) \wedge G)|-alternatives to c.d = {b.d}
#         |X| = < {b.c.d, b.d, c.d}, {a.b.c, a.b.c.d, a.d} >  (True in b.d)
#
# Total Run Time: 1.8092 seconds
#
# ========================================

# %% [markdown]
# ### CF_CM_15: Counterfactual Excluded Middle

# %%
run_example(counterfactual.CF_CM_15_example, "Counterfactual Excluded Middle")
# Out:
# ========================================
#
# EXAMPLE Counterfactual Excluded Middle: there is a countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
# Premise:
# 1. \neg A
#
# Conclusions:
# 2. (A \boxright B)
# 3. (A \boxright \neg B)
#
# Z3 Run Time: 0.0101 seconds
#
# ========================================
# State Space:
#   #b0000 = □
#   #b0001 = a
#   #b0010 = b
#   #b0011 = a.b (impossible)
#   #b0100 = c
#   #b0101 = a.c (world)
#   #b0110 = b.c
#   #b0111 = a.b.c (impossible)
#   #b1000 = d
#   #b1001 = a.d (world)
#   #b1010 = b.d
#   #b1011 = a.b.d (impossible)
#   #b1100 = c.d
#   #b1101 = a.c.d (impossible)
#   #b1110 = b.c.d (world)
#   #b1111 = a.b.c.d (impossible)
#
# The evaluation world is: b.c.d
#
# INTERPRETED PREMISE:
#
# 1.  |\neg A| = < {b.c.d, b.d}, {a, a.d} >  (True in b.c.d)
#       |A| = < {a, a.d}, {b.c.d, b.d} >  (False in b.c.d)
#
# INTERPRETED CONCLUSIONS:
#
# 2.  |(A \boxright B)| = < ∅, {□} >  (False in b.c.d)
#       |A| = < {a, a.d}, {b.c.d, b.d} >  (False in b.c.d)
#       |A|-alternatives to b.c.d = {a.c, a.d}
#         |B| = < {a.d}, {b.c.d, c} >  (True in a.d)
#         |B| = < {a.d}, {b.c.d, c} >  (False in a.c)
#
# 3.  |(A \boxright \neg B)| = < ∅, {□} >  (False in b.c.d)
#       |A| = < {a, a.d}, {b.c.d, b.d} >  (False in b.c.d)
#       |A|-alternatives to b.c.d = {a.c, a.d}
#         |\neg B| = < {b.c.d, c}, {a.d} >  (False in a.d)
#           |B| = < {a.d}, {b.c.d, c} >  (True in a.d)
#         |\neg B| = < {b.c.d, c}, {a.d} >  (True in a.c)
#           |B| = < {a.d}, {b.c.d, c} >  (False in a.c)
#
# Total Run Time: 0.2173 seconds
#
# ========================================

# %% [markdown]
# ### CF_CM_16: Simplification of Disjunctive Consequent

# %%
run_example(counterfactual.CF_CM_16_example, "Simplification of Disjunctive Consequent")
# Out:
# ========================================
#
# EXAMPLE Simplification of Disjunctive Consequent: there is a countermodel.
#
# Atomic States: 3
#
# Semantic Theory: Default Semantics
#
# Premises:
# 1. \neg A
# 2. (A \boxright (B \vee C))
#
# Conclusions:
# 3. (A \boxright B)
# 4. (A \boxright C)
#
# Z3 Run Time: 0.0047 seconds
#
# ========================================
# State Space:
#   #b000 = □
#   #b001 = a
#   #b010 = b
#   #b011 = a.b (world)
#   #b100 = c
#   #b101 = a.c (world)
#   #b110 = b.c (world)
#   #b111 = a.b.c (impossible)
#
# The evaluation world is: a.c
#
# INTERPRETED PREMISES:
#
# 1.  |\neg A| = < {a.c}, {a.b.c, b} >  (True in a.c)
#       |A| = < {a.b.c, b}, {a.c} >  (False in a.c)
#
# 2.  |(A \boxright (B \vee C))| = < {□}, ∅ >  (True in a.c)
#       |A| = < {a.b.c, b}, {a.c} >  (False in a.c)
#       |A|-alternatives to a.c = {a.b, b.c}
#         |(B \vee C)| = < {a.b, a.b.c, b.c}, {a.b.c, a.c} >  (True in b.c)
#           |B| = < {a.b}, {c} >  (False in b.c)
#           |C| = < {b.c}, {a.b, a.b.c, a.c} >  (True in b.c)
#         |(B \vee C)| = < {a.b, a.b.c, b.c}, {a.b.c, a.c} >  (True in a.b)
#           |B| = < {a.b}, {c} >  (True in a.b)
#           |C| = < {b.c}, {a.b, a.b.c, a.c} >  (False in a.b)
#
# INTERPRETED CONCLUSIONS:
#
# 3.  |(A \boxright B)| = < ∅, {□} >  (False in a.c)
#       |A| = < {a.b.c, b}, {a.c} >  (False in a.c)
#       |A|-alternatives to a.c = {a.b, b.c}
#         |B| = < {a.b}, {c} >  (False in b.c)
#         |B| = < {a.b}, {c} >  (True in a.b)
#
# 4.  |(A \boxright C)| = < ∅, {□} >  (False in a.c)
#       |A| = < {a.b.c, b}, {a.c} >  (False in a.c)
#       |A|-alternatives to a.c = {a.b, b.c}
#         |C| = < {b.c}, {a.b, a.b.c, a.c} >  (True in b.c)
#         |C| = < {b.c}, {a.b, a.b.c, a.c} >  (False in a.b)
#
# Total Run Time: 0.1231 seconds
#
# ========================================

# %% [markdown]
# ### CF_CM_17: Introduction of Disjunctive Antecedent

# %%
run_example(counterfactual.CF_CM_17_example, "Introduction of Disjunctive Antecedent")
# Out:
# ========================================
#
# EXAMPLE Introduction of Disjunctive Antecedent: there is a countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
# Premises:
# 1. (A \boxright C)
# 2. (B \boxright C)
#
# Conclusion:
# 3. ((A \vee B) \boxright C)
#
# Z3 Run Time: 0.015 seconds
#
# ========================================
# State Space:
#   #b0000 = □
#   #b0001 = a
#   #b0010 = b
#   #b0011 = a.b (world)
#   #b0100 = c
#   #b0101 = a.c (impossible)
#   #b0110 = b.c (world)
#   #b0111 = a.b.c (impossible)
#   #b1000 = d
#   #b1001 = a.d (world)
#   #b1010 = b.d (impossible)
#   #b1011 = a.b.d (impossible)
#   #b1100 = c.d (world)
#   #b1101 = a.c.d (impossible)
#   #b1110 = b.c.d (impossible)
#   #b1111 = a.b.c.d (impossible)
#
# The evaluation world is: a.b
#
# INTERPRETED PREMISES:
#
# 1.  |(A \boxright C)| = < {□}, ∅ >  (True in a.b)
#       |A| = < {a.b, a.b.c, a.b.c.d, a.b.d, b.c.d, c}, {a.d} >  (True in a.b)
#       |A|-alternatives to a.b = {a.b, b.c}
#         |C| = < {a.b.d, a.d, b}, {c.d} >  (True in a.b)
#         |C| = < {a.b.d, a.d, b}, {c.d} >  (True in b.c)
#
# 2.  |(B \boxright C)| = < {□}, ∅ >  (True in a.b)
#       |B| = < {a.b.c.d, a.b.d, a.c.d, d}, {a.b, a.b.c, b} >  (False in a.b)
#       |B|-alternatives to a.b = {a.d}
#         |C| = < {a.b.d, a.d, b}, {c.d} >  (True in a.d)
#
# INTERPRETED CONCLUSION:
#
# 3.  |((A \vee B) \boxright C)| = < ∅, {□} >  (False in a.b)
#       |(A \vee B)| = < {a.b, a.b.c, a.b.c.d, a.b.d, a.c.d, b.c.d, c, c.d, d}, {a.b.c.d, a.b.d} >  (True in a.b)
#         |A| = < {a.b, a.b.c, a.b.c.d, a.b.d, b.c.d, c}, {a.d} >  (True in a.b)
#         |B| = < {a.b.c.d, a.b.d, a.c.d, d}, {a.b, a.b.c, b} >  (False in a.b)
#       |(A \vee B)|-alternatives to a.b = {a.b, a.d, b.c, c.d}
#         |C| = < {a.b.d, a.d, b}, {c.d} >  (True in a.d)
#         |C| = < {a.b.d, a.d, b}, {c.d} >  (True in a.b)
#         |C| = < {a.b.d, a.d, b}, {c.d} >  (False in c.d)
#         |C| = < {a.b.d, a.d, b}, {c.d} >  (True in b.c)
#
# Total Run Time: 0.4431 seconds
#
# ========================================

# %% [markdown]
# ### CF_CM_18: Must Factivity

# %%
run_example(counterfactual.CF_CM_18_example, "Must Factivity")
# Out:
# ========================================
#
# EXAMPLE Must Factivity: there is a countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
# Premises:
# 1. A
# 2. B
#
# Conclusion:
# 3. (A \boxright B)
#
# Z3 Run Time: 0.0092 seconds
#
# ========================================
# State Space:
#   #b0000 = □
#   #b0001 = a
#   #b0010 = b
#   #b0011 = a.b
#   #b0100 = c
#   #b0101 = a.c
#   #b0110 = b.c
#   #b0111 = a.b.c (world)
#   #b1000 = d
#   #b1001 = a.d (world)
#   #b1010 = b.d
#   #b1011 = a.b.d (impossible)
#   #b1100 = c.d
#   #b1101 = a.c.d (impossible)
#   #b1110 = b.c.d (world)
#   #b1111 = a.b.c.d (impossible)
#
# The evaluation world is: b.c.d
#
# INTERPRETED PREMISES:
#
# 1.  |A| = < {a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b, b.c, b.c.d, c, c.d}, {a.d} >  (True in b.c.d)
#
# 2.  |B| = < {a.b.c.d, a.b.d, a.c.d, a.d, b.c.d, b.d, c.d, d}, {a.b.c} >  (True in b.c.d)
#
# INTERPRETED CONCLUSION:
#
# 3.  |(A \boxright B)| = < ∅, {□} >  (False in b.c.d)
#       |A| = < {a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d, b, b.c, b.c.d, c, c.d}, {a.d} >  (True in b.c.d)
#       |A|-alternatives to b.c.d = {a.b.c, b.c.d}
#         |B| = < {a.b.c.d, a.b.d, a.c.d, a.d, b.c.d, b.d, c.d, d}, {a.b.c} >  (True in b.c.d)
#         |B| = < {a.b.c.d, a.b.d, a.c.d, a.d, b.c.d, b.d, c.d, d}, {a.b.c} >  (False in a.b.c)
#
# Total Run Time: 0.2249 seconds
#
# ========================================

# %% [markdown]
# ### CF_CM_19: Counterfactual Exportation

# %%
run_example(counterfactual.CF_CM_19_example, "Counterfactual Exportation")
# Out:
# ========================================
#
# EXAMPLE Counterfactual Exportation: there is a countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
# Premise:
# 1. ((A \wedge B) \boxright C)
#
# Conclusion:
# 2. (A \boxright (B \boxright C))
#
# Z3 Run Time: 0.0156 seconds
#
# ========================================
# State Space:
#   #b0000 = □
#   #b0001 = a
#   #b0010 = b
#   #b0011 = a.b
#   #b0100 = c
#   #b0101 = a.c
#   #b0110 = b.c
#   #b0111 = a.b.c (world)
#   #b1000 = d
#   #b1001 = a.d
#   #b1010 = b.d
#   #b1011 = a.b.d (world)
#   #b1100 = c.d
#   #b1101 = a.c.d (world)
#   #b1110 = b.c.d (world)
#   #b1111 = a.b.c.d (impossible)
#
# The evaluation world is: a.c.d
#
# INTERPRETED PREMISE:
#
# 1.  |((A \wedge B) \boxright C)| = < {□}, ∅ >  (True in a.c.d)
#       |(A \wedge B)| = < {a.b.c, a.b.c.d}, {a.b.c.d, a.b.d, a.c.d, b.d} >  (False in a.c.d)
#         |A| = < {a.b.c.d, a.c}, {a.b.c.d, a.b.d, b.d} >  (True in a.c.d)
#         |B| = < {a.b.c, a.b.c.d, a.b.d, b, b.c.d}, {a.c.d} >  (False in a.c.d)
#       |(A \wedge B)|-alternatives to a.c.d = {a.b.c}
#         |C| = < {a.c}, {a.b.c.d, a.b.d, b.c.d} >  (True in a.b.c)
#
# INTERPRETED CONCLUSION:
#
# 2.  |(A \boxright (B \boxright C))| = < ∅, {□} >  (False in a.c.d)
#       |A| = < {a.b.c.d, a.c}, {a.b.c.d, a.b.d, b.d} >  (True in a.c.d)
#       |A|-alternatives to a.c.d = {a.c.d}
#         |(B \boxright C)| = < ∅, {□} >  (False in a.c.d)
#           |B| = < {a.b.c, a.b.c.d, a.b.d, b, b.c.d}, {a.c.d} >  (False in a.c.d)
#             |B|-alternatives to a.c.d = {a.b.c, a.b.d, b.c.d}
#               |C| = < {a.c}, {a.b.c.d, a.b.d, b.c.d} >  (False in a.b.d)
#               |C| = < {a.c}, {a.b.c.d, a.b.d, b.c.d} >  (False in b.c.d)
#               |C| = < {a.c}, {a.b.c.d, a.b.d, b.c.d} >  (True in a.b.c)
#
# Total Run Time: 2.1843 seconds
#
# ========================================

# %% [markdown]
# ### CF_CM_20: Counterfactual Exportation with Possibility

# %%
run_example(counterfactual.CF_CM_20_example, "Counterfactual Exportation with Possibility")
# Out:
# ========================================
#
# EXAMPLE Counterfactual Exportation with Possibility: there is a countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
# Premises:
# 1. ((A \wedge B) \boxright C)
# 2. \Diamond (A \wedge B)
#
# Conclusion:
# 3. (A \boxright (B \boxright C))
#
# Z3 Run Time: 0.0158 seconds
#
# ========================================
# State Space:
#   #b0000 = □
#   #b0001 = a (world)
#   #b0010 = b (world)
#   #b0011 = a.b (impossible)
#   #b0100 = c (impossible)
#   #b0101 = a.c (impossible)
#   #b0110 = b.c (impossible)
#   #b0111 = a.b.c (impossible)
#   #b1000 = d (world)
#   #b1001 = a.d (impossible)
#   #b1010 = b.d (impossible)
#   #b1011 = a.b.d (impossible)
#   #b1100 = c.d (impossible)
#   #b1101 = a.c.d (impossible)
#   #b1110 = b.c.d (impossible)
#   #b1111 = a.b.c.d (impossible)
#
# The evaluation world is: a
#
# INTERPRETED PREMISES:
#
# 1.  |((A \wedge B) \boxright C)| = < {□}, ∅ >  (True in a)
#       |(A \wedge B)| = < {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d}, {b, b.d, d} >  (True in a)
#         |A| = < {a, a.b.c.d, a.c, a.c.d}, {b, b.d, d} >  (True in a)
#         |B| = < {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c.d, b, b.c.d}, {d} >  (True in a)
#       |(A \wedge B)|-alternatives to a = {a}
#         |C| = < {a, a.d, d}, {b} >  (True in a)
#
# 2.  |\Diamond (A \wedge B)| = < {□}, ∅ >  (True in a)
#       |(A \wedge B)| = < {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d}, {b, b.d, d} >  (True in a)
#         |A| = < {a, a.b.c.d, a.c, a.c.d}, {b, b.d, d} >  (True in a)
#         |B| = < {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c.d, b, b.c.d}, {d} >  (True in a)
#       |(A \wedge B)| = < {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d}, {b, b.d, d} >  (False in b)
#         |A| = < {a, a.b.c.d, a.c, a.c.d}, {b, b.d, d} >  (False in b)
#         |B| = < {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c.d, b, b.c.d}, {d} >  (True in b)
#       |(A \wedge B)| = < {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c, a.c.d}, {b, b.d, d} >  (False in d)
#         |A| = < {a, a.b.c.d, a.c, a.c.d}, {b, b.d, d} >  (False in d)
#         |B| = < {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c.d, b, b.c.d}, {d} >  (False in d)
#
# INTERPRETED CONCLUSION:
#
# 3.  |(A \boxright (B \boxright C))| = < ∅, {□} >  (False in a)
#       |A| = < {a, a.b.c.d, a.c, a.c.d}, {b, b.d, d} >  (True in a)
#       |A|-alternatives to a = {a}
#         |(B \boxright C)| = < ∅, {□} >  (False in a)
#           |B| = < {a, a.b, a.b.c, a.b.c.d, a.b.d, a.c.d, b, b.c.d}, {d} >  (True in a)
#             |B|-alternatives to a = {a, b}
#               |C| = < {a, a.d, d}, {b} >  (False in b)
#               |C| = < {a, a.d, d}, {b} >  (True in a)
#
# Total Run Time: 2.3351 seconds
#
# ========================================

# %% [markdown]
# ### CF_CM_21: Counterfactual Negation

# %%
run_example(counterfactual.CF_CM_21_example, "Counterfactual Negation")
# Out:
# ========================================
#
# EXAMPLE Counterfactual Negation: there is a countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
# Premises:
# 1. \neg A
# 2. \neg (A \boxright B)
#
# Conclusion:
# 3. (A \boxright \neg B)
#
# Z3 Run Time: 0.0106 seconds
#
# ========================================
# State Space:
#   #b0000 = □
#   #b0001 = a
#   #b0010 = b
#   #b0011 = a.b (world)
#   #b0100 = c
#   #b0101 = a.c (impossible)
#   #b0110 = b.c (world)
#   #b0111 = a.b.c (impossible)
#   #b1000 = d
#   #b1001 = a.d (world)
#   #b1010 = b.d (impossible)
#   #b1011 = a.b.d (impossible)
#   #b1100 = c.d (impossible)
#   #b1101 = a.c.d (impossible)
#   #b1110 = b.c.d (impossible)
#   #b1111 = a.b.c.d (impossible)
#
# The evaluation world is: a.b
#
# INTERPRETED PREMISES:
#
# 1.  |\neg A| = < {a.b, a.b.c, a.b.c.d, a.c.d}, {a.b.c.d, a.c.d, a.d, b.c.d, c, c.d} >  (True in a.b)
#       |A| = < {a.b.c.d, a.c.d, a.d, b.c.d, c, c.d}, {a.b, a.b.c, a.b.c.d, a.c.d} >  (False in a.b)
#
# 2.  |\neg (A \boxright B)| = < {□}, ∅ >  (True in a.b)
#       |(A \boxright B)| = < ∅, {□} >  (False in a.b)
#         |A| = < {a.b.c.d, a.c.d, a.d, b.c.d, c, c.d}, {a.b, a.b.c, a.b.c.d, a.c.d} >  (False in a.b)
#           |A|-alternatives to a.b = {a.d, b.c}
#             |B| = < {b}, {a.d} >  (True in b.c)
#             |B| = < {b}, {a.d} >  (False in a.d)
#
# INTERPRETED CONCLUSION:
#
# 3.  |(A \boxright \neg B)| = < ∅, {□} >  (False in a.b)
#       |A| = < {a.b.c.d, a.c.d, a.d, b.c.d, c, c.d}, {a.b, a.b.c, a.b.c.d, a.c.d} >  (False in a.b)
#       |A|-alternatives to a.b = {a.d, b.c}
#         |\neg B| = < {a.d}, {b} >  (False in b.c)
#           |B| = < {b}, {a.d} >  (True in b.c)
#         |\neg B| = < {a.d}, {b} >  (True in a.d)
#           |B| = < {b}, {a.d} >  (False in a.d)
#
# Total Run Time: 0.324 seconds
#
# ========================================

# %% [markdown]
# ## Theorems
#
# Now let's examine some key theorems from counterfactual logic.

# %% [markdown]
# ### CF_TH_1: Counterfactual Identity

# %%
run_example(counterfactual.CF_TH_1_example, "Counterfactual Identity")
# Out:
# ========================================
#
# EXAMPLE Counterfactual Identity: there is no countermodel.
#
# Atomic States: 2
#
# Semantic Theory: Default Semantics
#
# Premise:
#
# Conclusion:
# 1. (A \boxright A)
#
# Z3 Run Time: 0.0022 seconds
#
# ========================================

# %% [markdown]
# ### CF_TH_2: Counterfactual Modus Ponens

# %%
run_example(counterfactual.CF_TH_2_example, "Counterfactual Modus Ponens")
# Out:
# ========================================
#
# EXAMPLE Counterfactual Modus Ponens: there is no countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
# Premises:
# 1. A
# 2. (A \boxright B)
#
# Conclusion:
# 3. B
#
# Z3 Run Time: 0.018 seconds
#
# ========================================

# %% [markdown]
# ### CF_TH_3: Weakened Transitivity

# %%
run_example(counterfactual.CF_TH_3_example, "Weakened Transitivity")
# Out:
# ========================================
#
# EXAMPLE Weakened Transitivity: there is no countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
# Premises:
# 1. (A \boxright B)
# 2. ((A \wedge B) \boxright C)
#
# Conclusion:
# 3. (A \boxright C)
#
# Z3 Run Time: 0.1385 seconds
#
# ========================================

# %% [markdown]
# ### CF_TH_4: Antecedent Disjunction to Conjunction

# %%
run_example(counterfactual.CF_TH_4_example, "Antecedent Disjunction to Conjunction")
# Out:
# ========================================
#
# EXAMPLE Antecedent Disjunction to Conjunction: there is no countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
# Premise:
# 1. ((A \vee B) \boxright C)
#
# Conclusion:
# 2. ((A \wedge B) \boxright C)
#
# Z3 Run Time: 0.0344 seconds
#
# ========================================

# %% [markdown]
# ### CF_TH_5: Simplification of Disjunctive Antecedent

# %%
run_example(counterfactual.CF_TH_5_example, "Simplification of Disjunctive Antecedent")
# Out:
# ========================================
#
# EXAMPLE Simplification of Disjunctive Antecedent: there is no countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
# Premise:
# 1. ((A \vee B) \boxright C)
#
# Conclusion:
# 2. (A \boxright C)
#
# Z3 Run Time: 0.0372 seconds
#
# ========================================

# %% [markdown]
# ### CF_TH_6: Double Simplification of Disjunctive Antecedent

# %%
run_example(counterfactual.CF_TH_6_example, "Double Simplification of Disjunctive Antecedent")
# Out:
# ========================================
#
# EXAMPLE Double Simplification of Disjunctive Antecedent: there is no countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
# Premise:
# 1. ((A \vee B) \boxright C)
#
# Conclusion:
# 2. ((A \boxright C) \wedge (B \boxright C))
#
# Z3 Run Time: 0.0528 seconds
#
# ========================================

# %% [markdown]
# ### CF_TH_7: Disjunctive Antecedent

# %%
run_example(counterfactual.CF_TH_7_example, "Disjunctive Antecedent")
# Out:
# ========================================
#
# EXAMPLE Disjunctive Antecedent: there is no countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
# Premises:
# 1. (A \boxright C)
# 2. (B \boxright C)
# 3. ((A \wedge B) \boxright C)
#
# Conclusion:
# 4. ((A \vee B) \boxright C)
#
# Z3 Run Time: 0.0393 seconds
#
# ========================================

# %% [markdown]
# ### CF_TH_8: Conjunctive Consequent to Left

# %%
run_example(counterfactual.CF_TH_8_example, "Conjunctive Consequent to Left")
# Out:
# ========================================
#
# EXAMPLE Conjunctive Consequent to Left: there is no countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
# Premise:
# 1. (A \boxright (B \wedge C))
#
# Conclusion:
# 2. (A \boxright B)
#
# Z3 Run Time: 0.0272 seconds
#
# ========================================

# %% [markdown]
# ### CF_TH_9: Conjunction of Consequents

# %%
run_example(counterfactual.CF_TH_9_example, "Conjunction of Consequents")
# Out:
# ========================================
#
# EXAMPLE Conjunction of Consequents: there is no countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
# Premises:
# 1. (A \boxright B)
# 2. (A \boxright C)
#
# Conclusion:
# 3. (A \boxright (B \wedge C))
#
# Z3 Run Time: 0.137 seconds
#
# ========================================

# %% [markdown]
# ### CF_TH_10: Might Factivity

# %%
run_example(counterfactual.CF_TH_10_example, "Might Factivity")
# Out:
# ========================================
#
# EXAMPLE Might Factivity: there is no countermodel.
#
# Atomic States: 4
#
# Semantic Theory: Default Semantics
#
# Premises:
# 1. A
# 2. B
#
# Conclusion:
# 3. (A \diamondright B)
#
# Z3 Run Time: 0.0188 seconds
#
# ========================================

# %% [markdown]
# ### CF_TH_11: Definition of Necessity

# %%
run_example(counterfactual.CF_TH_11_example, "Definition of Necessity")
# Out:
# ========================================
#
# EXAMPLE Definition of Necessity: there is no countermodel.
#
# Atomic States: 3
#
# Semantic Theory: Default Semantics
#
# Premise:
# 1. \Box A
#
# Conclusion:
# 2. (\top \boxright A)
#
# Z3 Run Time: 0.0034 seconds
#
# ========================================

# %% [markdown]
# ### CF_TH_12: Definition of Necessity (Alternative)

# %%
run_example(counterfactual.CF_TH_12_example, "Definition of Necessity (Alternative)")
# Out:
# ========================================
#
# EXAMPLE Definition of Necessity (Alternative): there is no countermodel.
#
# Atomic States: 3
#
# Semantic Theory: Default Semantics
#
# Premise:
# 1. (\neg A \boxright \bot)
#
# Conclusion:
# 2. (\top \boxright A)
#
# Z3 Run Time: 0.004 seconds
#
# ========================================

# %% [markdown]
# ## Summary
#
# This notebook demonstrates the key countermodels and theorems in counterfactual logic using the default theory of the ModelChecker framework. The examples showcase various properties of the counterfactual operators including antecedent strengthening, contraposition, transitivity, and interactions with modal operators.
