# %% [markdown]
# ## `model_checker` Python API Jupyter notebook
# This jupyter notebook will go through the basics of how to use the `model_checker` package from scratch in python. It will also go over how to use some of the built-in features that make exploring semantics already in `theory_lib` much easier.

# %% [markdown]
# First, the basic imports. If you want to make a theory from scratch, see the `semantic.py` and `operator.py` files for the theories in `theory_lib`. This notebook will use the semantics for Bernard and Champollion's exclusion semantics (which is what the second import is).

# %%
import model_checker as mc
from model_checker.theory_lib import exclusion
# from model_checker import exxclusion

# %% [markdown]
# First we need operators. We can define these, or, since we are using the exclusion semantics as an example, we can import them from a theory in theory_lib. Even with that, we have two options. We can import a group of default operators for that theory, or we can import specific operators from the operator file. In either case, operators are imported through a Syntactic.OperatorCollection object:

# %%
# import the default operators of the theory:
operators = exclusion.exclusion_operators
assert isinstance(operators, mc.syntactic.OperatorCollection)

# import specific operators manually:
operators = mc.syntactic.OperatorCollection(exclusion.operators.ExclusionOperator, # Negation
                                            exclusion.operators.UniAndOperator, # And
                                            exclusion.operators.UniOrOperator, # Or
                                            exclusion.operators.UniIdentityOperator # Propositional Identity
                                            )

# %% [markdown]
# Since the default `OperatorCollection` object for the exclusion semantics contains exactly those operators seen in the manual import, the two `operators` objects above are equivalent (comparison for equality is not (yet?) supported for `OperatorCollection` objects).
#
# We now need to pick a theorem to test. The operators have names associated to them, and it is these that you type in the string that represents the theorem. You can see the names of these operators by printing them:

# %%
for operator in operators:
    print(operator) # hopefully it's clear which operators correspond to which!
# Out:
# \exclude
# \uniwedge
# \univee
# \uniequiv

# %% [markdown]
# Now we need to import the syntax. To do this, we need a theorem to get a model for. A `Syntax` object will represent the theorems inputted as strings in a way that `model_checker` can understand. It doesn't really have any attributes useful to the user. For more details, see the `syntactic.py` module of `model_checker`.

# %%
premises = ["\\exclude (P \\uniwedge Q)"]
conclusions = ["(\\exclude P \\univee \\exclude Q)"]
syntax = mc.syntactic.Syntax(premises, conclusions, operators)

# %% [markdown]
# Now we make the semantics. We will just use the one in the `theory_lib` for exclusion semantics. A `Semantics` object, of which `ExclusionSemantics` is an instance, has limited user-useful attributes, which are shown below. For more details, see the `SemanticDefaults` class of the `model.py` module of `model_checker` and the `[X]Semantics` object found in the `semantic.py` module of the theory you are interested in. To initialize as a `Semantics` object, feed it the number of atomic states you want in your model. We represent this value with `N`. [UPDATE: This has changed. Now you feed it the settings you want the semantics to have. We will just use the theory's default settings for ease. ]

# %%
# N = 3 # number of atomics tates desired
default_settings = exclusion.ExclusionSemantics.DEFAULT_EXAMPLE_SETTINGS
print(default_settings)
semantics = exclusion.ExclusionSemantics(default_settings)
print(str(semantics))
print(semantics.N) # number of atomic states in the model
# print(semantics.DEFAULT_EXAMPLE_SETTINGS) # default settings. Will be useful in next step.
# Out:
# {'N': 3, 'possible': False, 'contingent': False, 'non_empty': False, 'non_null': False, 'disjoint': False, 'fusion_closure': False, 'iterate': 1, 'max_time': 1, 'expectation': None}
# <model_checker.theory_lib.exclusion.semantic.ExclusionSemantics object at 0x1135c8d90>
# 3

# %% [markdown]
# The last ingredient we need before we get the ball rolling is a `Proposition` class. As with the semantics there is a default for the exclusion semantics in its module; for details on how to make one from the ground up, see the `PropositionDefaults` class in the `model.py` module of `model_checker` and the `[X]Proposition` object in the `semantic.py` modules of the theories in `theory_lib`.

# %%
proposition_class = exclusion.UnilateralProposition

# %% [markdown]
# Now that we have a syntax with a specific example, a semantics, and a definition of a proposition, we can in principle find all the constraints that would be needed to see if a countermodel exists. And indeed this is what we do next, by defining a `ModelConstraints` object. Since we can impose additional constraints on the model (e.g., only contingent sentences, only non-empty verifiers, only non-null falsifiers), we also pass a `settings` dictionary into the `ModelConstraints` object. The `ExclusionSemantics` has a default setting dictionary, which was printed in the cell above; we will use this for now.
#
# A `Model_Constraints` object has many user-useful attributes, mainly in the form of Z3 constraints. Z3's constraints are in prefix notation; also for more details see the specific implementations of constraints in the `Semantics` object and `Proposition` object you have.

# %%
settings = semantics.DEFAULT_EXAMPLE_SETTINGS
model_constraints = mc.model.ModelConstraints(settings, syntax, semantics, proposition_class)

# print(model_constraints.frame_constraints)
# print(model_constraints.model_constraints)
# print(model_constraints.premise_constraints)
# print(model_constraints.conclusion_constraints)
print(model_constraints.all_constraints)
# Out:
# [And(Not(Or(Or(And(0 | w == w, 0 | w == w, excludes(0, 0)),
#               And(0 | w == w, 1 | w == w, excludes(0, 1)),
#               And(0 | w == w, 2 | w == w, excludes(0, 2)),
#               And(0 | w == w, 3 | w == w, excludes(0, 3)),
#               And(0 | w == w, 4 | w == w, excludes(0, 4)),
#               And(0 | w == w, 5 | w == w, excludes(0, 5)),
#               And(0 | w == w, 6 | w == w, excludes(0, 6)),
#               And(0 | w == w, 7 | w == w, excludes(0, 7))),
#            Or(And(1 | w == w, 0 | w == w, excludes(1, 0)),
#               And(1 | w == w, 1 | w == w, excludes(1, 1)),
#               And(1 | w == w, 2 | w == w, excludes(1, 2)),
#               And(1 | w == w, 3 | w == w, excludes(1, 3)),
#               And(1 | w == w, 4 | w == w, excludes(1, 4)),
#               And(1 | w == w, 5 | w == w, excludes(1, 5)),
#               And(1 | w == w, 6 | w == w, excludes(1, 6)),
#               And(1 | w == w, 7 | w == w, excludes(1, 7))),
#            Or(And(2 | w == w, 0 | w == w, excludes(2, 0)),
#               And(2 | w == w, 1 | w == w, excludes(2, 1)),
#               And(2 | w == w, 2 | w == w, excludes(2, 2)),
#               And(2 | w == w, 3 | w == w, excludes(2, 3)),
#               And(2 | w == w, 4 | w == w, excludes(2, 4)),
#               And(2 | w == w, 5 | w == w, excludes(2, 5)),
#               And(2 | w == w, 6 | w == w, excludes(2, 6)),
#               And(2 | w == w, 7 | w == w, excludes(2, 7))),
#            Or(And(3 | w == w, 0 | w == w, excludes(3, 0)),
#               And(3 | w == w, 1 | w == w, excludes(3, 1)),
#               And(3 | w == w, 2 | w == w, excludes(3, 2)),
#               And(3 | w == w, 3 | w == w, excludes(3, 3)),
#               And(3 | w == w, 4 | w == w, excludes(3, 4)),
#               And(3 | w == w, 5 | w == w, excludes(3, 5)),
#               And(3 | w == w, 6 | w == w, excludes(3, 6)),
#               And(3 | w == w, 7 | w == w, excludes(3, 7))),
#            Or(And(4 | w == w, 0 | w == w, excludes(4, 0)),
#               And(4 | w == w, 1 | w == w, excludes(4, 1)),
#               And(4 | w == w, 2 | w == w, excludes(4, 2)),
#               And(4 | w == w, 3 | w == w, excludes(4, 3)),
#               And(4 | w == w, 4 | w == w, excludes(4, 4)),
#               And(4 | w == w, 5 | w == w, excludes(4, 5)),
#               And(4 | w == w, 6 | w == w, excludes(4, 6)),
#               And(4 | w == w, 7 | w == w, excludes(4, 7))),
#            Or(And(5 | w == w, 0 | w == w, excludes(5, 0)),
#               And(5 | w == w, 1 | w == w, excludes(5, 1)),
#               And(5 | w == w, 2 | w == w, excludes(5, 2)),
#               And(5 | w == w, 3 | w == w, excludes(5, 3)),
#               And(5 | w == w, 4 | w == w, excludes(5, 4)),
#               And(5 | w == w, 5 | w == w, excludes(5, 5)),
#               And(5 | w == w, 6 | w == w, excludes(5, 6)),
#               And(5 | w == w, 7 | w == w, excludes(5, 7))),
#            Or(And(6 | w == w, 0 | w == w, excludes(6, 0)),
#               And(6 | w == w, 1 | w == w, excludes(6, 1)),
#               And(6 | w == w, 2 | w == w, excludes(6, 2)),
#               And(6 | w == w, 3 | w == w, excludes(6, 3)),
#               And(6 | w == w, 4 | w == w, excludes(6, 4)),
#               And(6 | w == w, 5 | w == w, excludes(6, 5)),
#               And(6 | w == w, 6 | w == w, excludes(6, 6)),
#               And(6 | w == w, 7 | w == w, excludes(6, 7))),
#            Or(And(7 | w == w, 0 | w == w, excludes(7, 0)),
#               And(7 | w == w, 1 | w == w, excludes(7, 1)),
#               And(7 | w == w, 2 | w == w, excludes(7, 2)),
#               And(7 | w == w, 3 | w == w, excludes(7, 3)),
#               And(7 | w == w, 4 | w == w, excludes(7, 4)),
#               And(7 | w == w, 5 | w == w, excludes(7, 5)),
#               And(7 | w == w, 6 | w == w, excludes(7, 6)),
#               And(7 | w == w, 7 | w == w, excludes(7, 7))))),
#     Not(Or(And(And(w | 0 == 0, w != 0),
#                Not(Or(Or(And(0 | 0 == 0,
#                              0 | 0 == 0,
#                              excludes(0, 0)),
#                          And(0 | 0 == 0,
#                              1 | 0 == 0,
#                              excludes(0, 1)),
#                          And(0 | 0 == 0,
#                              2 | 0 == 0,
#                              excludes(0, 2)),
#                          And(0 | 0 == 0,
#                              3 | 0 == 0,
#                              excludes(0, 3)),
#                          And(0 | 0 == 0,
#                              4 | 0 == 0,
#                              excludes(0, 4)),
#                          And(0 | 0 == 0,
#                              5 | 0 == 0,
#                              excludes(0, 5)),
#                          And(0 | 0 == 0,
#                              6 | 0 == 0,
#                              excludes(0, 6)),
#                          And(0 | 0 == 0,
#                              7 | 0 == 0,
#                              excludes(0, 7))),
#                       Or(And(1 | 0 == 0,
#                              0 | 0 == 0,
#                              excludes(1, 0)),
#                          And(1 | 0 == 0,
#                              1 | 0 == 0,
#                              excludes(1, 1)),
#                          And(1 | 0 == 0,
#                              2 | 0 == 0,
#                              excludes(1, 2)),
#                          And(1 | 0 == 0,
#                              3 | 0 == 0,
#                              excludes(1, 3)),
#                          And(1 | 0 == 0,
#                              4 | 0 == 0,
#                              excludes(1, 4)),
#                          And(1 | 0 == 0,
#                              5 | 0 == 0,
#                              excludes(1, 5)),
#                          And(1 | 0 == 0,
#                              6 | 0 == 0,
#                              excludes(1, 6)),
#                          And(1 | 0 == 0,
#                              7 | 0 == 0,
#                              excludes(1, 7))),
#                       Or(And(2 | 0 == 0,
#                              0 | 0 == 0,
#                              excludes(2, 0)),
#                          And(2 | 0 == 0,
#                              1 | 0 == 0,
#                              excludes(2, 1)),
#                          And(2 | 0 == 0,
#                              2 | 0 == 0,
#                              excludes(2, 2)),
#                          And(2 | 0 == 0,
#                              3 | 0 == 0,
#                              excludes(2, 3)),
#                          And(2 | 0 == 0,
#                              4 | 0 == 0,
#                              excludes(2, 4)),
#                          And(2 | 0 == 0,
#                              5 | 0 == 0,
#                              excludes(2, 5)),
#                          And(2 | 0 == 0,
#                              6 | 0 == 0,
#                              excludes(2, 6)),
#                          And(2 | 0 == 0,
#                              7 | 0 == 0,
#                              excludes(2, 7))),
#                       Or(And(3 | 0 == 0,
#                              0 | 0 == 0,
#                              excludes(3, 0)),
#                          And(3 | 0 == 0,
#                              1 | 0 == 0,
#                              excludes(3, 1)),
#                          And(3 | 0 == 0,
#                              2 | 0 == 0,
#                              excludes(3, 2)),
#                          And(3 | 0 == 0,
#                              3 | 0 == 0,
#                              excludes(3, 3)),
#                          And(3 | 0 == 0,
#                              4 | 0 == 0,
#                              excludes(3, 4)),
#                          And(3 | 0 == 0,
#                              5 | 0 == 0,
#                              excludes(3, 5)),
#                          And(3 | 0 == 0,
#                              6 | 0 == 0,
#                              excludes(3, 6)),
#                          And(3 | 0 == 0,
#                              7 | 0 == 0,
#                              excludes(3, 7))),
#                       Or(And(4 | 0 == 0,
#                              0 | 0 == 0,
#                              excludes(4, 0)),
#                          And(4 | 0 == 0,
#                              1 | 0 == 0,
#                              excludes(4, 1)),
#                          And(4 | 0 == 0,
#                              2 | 0 == 0,
#                              excludes(4, 2)),
#                          And(4 | 0 == 0,
#                              3 | 0 == 0,
#                              excludes(4, 3)),
#                          And(4 | 0 == 0,
#                              4 | 0 == 0,
#                              excludes(4, 4)),
#                          And(4 | 0 == 0,
#                              5 | 0 == 0,
#                              excludes(4, 5)),
#                          And(4 | 0 == 0,
#                              6 | 0 == 0,
#                              excludes(4, 6)),
#                          And(4 | 0 == 0,
#                              7 | 0 == 0,
#                              excludes(4, 7))),
#                       Or(And(5 | 0 == 0,
#                              0 | 0 == 0,
#                              excludes(5, 0)),
#                          And(5 | 0 == 0,
#                              1 | 0 == 0,
#                              excludes(5, 1)),
#                          And(5 | 0 == 0,
#                              2 | 0 == 0,
#                              excludes(5, 2)),
#                          And(5 | 0 == 0,
#                              3 | 0 == 0,
#                              excludes(5, 3)),
#                          And(5 | 0 == 0,
#                              4 | 0 == 0,
#                              excludes(5, 4)),
# ..., And(And(Implies(excludes(0, 0), excludes(0, 0)),
#         Implies(excludes(0, 1), excludes(1, 0)),
#         Implies(excludes(0, 2), excludes(2, 0)),
#         Implies(excludes(0, 3), excludes(3, 0)),
#         Implies(excludes(0, 4), excludes(4, 0)),
#         Implies(excludes(0, 5), excludes(5, 0)),
#         Implies(excludes(0, 6), excludes(6, 0)),
#         Implies(excludes(0, 7), excludes(7, 0))),
#     And(Implies(excludes(1, 0), excludes(0, 1)),
#         Implies(excludes(1, 1), excludes(1, 1)),
#         Implies(excludes(1, 2), excludes(2, 1)),
#         Implies(excludes(1, 3), excludes(3, 1)),
#         Implies(excludes(1, 4), excludes(4, 1)),
#         Implies(excludes(1, 5), excludes(5, 1)),
#         Implies(excludes(1, 6), excludes(6, 1)),
#         Implies(excludes(1, 7), excludes(7, 1))),
#     And(Implies(excludes(2, 0), excludes(0, 2)),
#         Implies(excludes(2, 1), excludes(1, 2)),
#         Implies(excludes(2, 2), excludes(2, 2)),
#         Implies(excludes(2, 3), excludes(3, 2)),
#         Implies(excludes(2, 4), excludes(4, 2)),
#         Implies(excludes(2, 5), excludes(5, 2)),
#         Implies(excludes(2, 6), excludes(6, 2)),
#         Implies(excludes(2, 7), excludes(7, 2))),
#     And(Implies(excludes(3, 0), excludes(0, 3)),
#         Implies(excludes(3, 1), excludes(1, 3)),
#         Implies(excludes(3, 2), excludes(2, 3)),
#         Implies(excludes(3, 3), excludes(3, 3)),
#         Implies(excludes(3, 4), excludes(4, 3)),
#         Implies(excludes(3, 5), excludes(5, 3)),
#         Implies(excludes(3, 6), excludes(6, 3)),
#         Implies(excludes(3, 7), excludes(7, 3))),
#     And(Implies(excludes(4, 0), excludes(0, 4)),
#         Implies(excludes(4, 1), excludes(1, 4)),
#         Implies(excludes(4, 2), excludes(2, 4)),
#         Implies(excludes(4, 3), excludes(3, 4)),
#         Implies(excludes(4, 4), excludes(4, 4)),
#         Implies(excludes(4, 5), excludes(5, 4)),
#         Implies(excludes(4, 6), excludes(6, 4)),
#         Implies(excludes(4, 7), excludes(7, 4))),
#     And(Implies(excludes(5, 0), excludes(0, 5)),
#         Implies(excludes(5, 1), excludes(1, 5)),
#         Implies(excludes(5, 2), excludes(2, 5)),
#         Implies(excludes(5, 3), excludes(3, 5)),
#         Implies(excludes(5, 4), excludes(4, 5)),
#         Implies(excludes(5, 5), excludes(5, 5)),
#         Implies(excludes(5, 6), excludes(6, 5)),
#         Implies(excludes(5, 7), excludes(7, 5))),
#     And(Implies(excludes(6, 0), excludes(0, 6)),
#         Implies(excludes(6, 1), excludes(1, 6)),
#         Implies(excludes(6, 2), excludes(2, 6)),
#         Implies(excludes(6, 3), excludes(3, 6)),
#         Implies(excludes(6, 4), excludes(4, 6)),
#         Implies(excludes(6, 5), excludes(5, 6)),
#         Implies(excludes(6, 6), excludes(6, 6)),
#         Implies(excludes(6, 7), excludes(7, 6))),
#     And(Implies(excludes(7, 0), excludes(0, 7)),
#         Implies(excludes(7, 1), excludes(1, 7)),
#         Implies(excludes(7, 2), excludes(2, 7)),
#         Implies(excludes(7, 3), excludes(3, 7)),
#         Implies(excludes(7, 4), excludes(4, 7)),
#         Implies(excludes(7, 5), excludes(5, 7)),
#         Implies(excludes(7, 6), excludes(6, 7)),
#         Implies(excludes(7, 7), excludes(7, 7)))), And(And(Implies(And(And(Not(Or(Or(And(0 | 0 == 0,
#                                       0 | 0 == 0,
#                                       excludes(0, 0)),
#                                   And(0 | 0 == 0,
#                                       1 | 0 == 0,
#                                       excludes(0, 1)),
#                                   And(0 | 0 == 0,
#                                       2 | 0 == 0,
#                                       excludes(0, 2)),
#                                   And(0 | 0 == 0,
#                                       3 | 0 == 0,
#                                       excludes(0, 3)),
#                                   And(0 | 0 == 0,
#                                       4 | 0 == 0,
#                                       excludes(0, 4)),
#                                   And(0 | 0 == 0,
#                                       5 | 0 == 0,
#                                       excludes(0, 5)),
#                                   And(0 | 0 == 0,
#                                       6 | 0 == 0,
#                                       excludes(0, 6)),
#                                   And(0 | 0 == 0,
#                                       7 | 0 == 0,
#                                       excludes(0, 7))),
#                                Or(And(1 | 0 == 0,
#                                       0 | 0 == 0,
#                                       excludes(1, 0)),
#                                   And(1 | 0 == 0,
#                                       1 | 0 == 0,
#                                       excludes(1, 1)),
#                                   And(1 | 0 == 0,
#                                       2 | 0 == 0,
#                                       excludes(1, 2)),
#                                   And(1 | 0 == 0,
#                                       3 | 0 == 0,
#                                       excludes(1, 3)),
#                                   And(1 | 0 == 0,
#                                       4 | 0 == 0,
#                                       excludes(1, 4)),
#                                   And(1 | 0 == 0,
#                                       5 | 0 == 0,
#                                       excludes(1, 5)),
#                                   And(1 | 0 == 0,
#                                       6 | 0 == 0,
#                                       excludes(1, 6)),
#                                   And(1 | 0 == 0,
#                                       7 | 0 == 0,
#                                       excludes(1, 7))),
#                                Or(And(2 | 0 == 0,
#                                       0 | 0 == 0,
#                                       excludes(2, 0)),
#                                   And(2 | 0 == 0,
#                                       1 | 0 == 0,
#                                       excludes(2, 1)),
#                                   And(2 | 0 == 0,
#                                       2 | 0 == 0,
#                                       excludes(2, 2)),
#                                   And(2 | 0 == 0,
#                                       3 | 0 == 0,
#                                       excludes(2, 3)),
#                                   And(2 | 0 == 0,
#                                       4 | 0 == 0,
#                                       excludes(2, 4)),
#                                   And(2 | 0 == 0,
#                                       5 | 0 == 0,
#                                       excludes(2, 5)),
#                                   And(2 | 0 == 0,
#                                       6 | 0 == 0,
#                                       excludes(2, 6)),
#                                   And(2 | 0 == 0,
#                                       7 | 0 == 0,
#                                       excludes(2, 7))),
#                                Or(And(3 | 0 == 0,
#                                       0 | 0 == 0,
#                                       excludes(3, 0)),
#                                   And(3 | 0 == 0,
#                                       1 | 0 == 0,
#                                       excludes(3, 1)),
#                                   And(3 | 0 == 0,
#                                       2 | 0 == 0,
#                                       excludes(3, 2)),
#                                   And(3 | 0 == 0,
#                                       3 | 0 == 0,
#                                       excludes(3, 3)),
#                                   And(3 | 0 == 0,
#                                       4 | 0 == 0,
#                                       excludes(3, 4)),
#                                   And(3 | 0 == 0,
#                                       5 | 0 == 0,
#                                       excludes(3, 5)),
#                                   And(3 | 0 == 0,
#                                       6 | 0 == 0,
#                                       excludes(3, 6)),
#                                   And(3 | 0 == 0,
#                                       7 | 0 == 0,
#                                       excludes(3, 7))),
#                                Or(And(4 | 0 == 0,
#                                       0 | 0 == 0,
#                                       excludes(4, 0)),
#                                   And(4 | 0 == 0,
#                                       1 | 0 == 0,
#                                       excludes(4, 1)),
#                                   And(4 | 0 == 0,
#                                       2 | 0 == 0,
#                                       excludes(4, 2)),
#                                   And(4 | 0 == 0,
#                                       3 | 0 == 0,
#                                       excludes(4, 3)),
#                                   And(4 | 0 == 0,
#                                       4 | 0 == 0,
#                                       excludes(4, 4)),
#                                   And(4 | 0 == 0,
#                                       5 | 0 == 0,
#                                       excludes(4, 5)),
#                                   And(4 | 0 == 0,
#                                       6 | 0 == 0,
#                                       excludes(4, 6)),
#                                   And(4 | 0 == 0,
#                                       7 | 0 == 0,
#                                       excludes(4, 7))),
#                                Or(And(5 | 0 == 0,
#                                       0 | 0 == 0,
#                                       excludes(5, 0)),
#                                   And(5 | 0 == 0,
#                                       1 | 0 == 0,
#                                       excludes(5, 1)),
#                                   And(5 | 0 == 0,
#                                       2 | 0 == 0,
#                                       excludes(5, 2)),
#                                   And(5 | 0 == 0,
#                                       3 | 0 == 0,
#                                       excludes(5, 3)),
#                                   And(5 | 0 == 0,
#                                       4 | 0 == 0,
#                                       excludes(5, 4)),
#                                   And(5 | 0 == 0,
#                                       5 | 0 == 0,
#                                       excludes(5, 5)),
#                                   And(5 | 0 == 0,
#                                       6 | 0 == 0,
#                                       excludes(5, 6)),
#                                   And(5 | 0 == 0,
#                                       7 | 0 == 0,
#                                       excludes(5, 7))),
#                                Or(And(6 | 0 == 0,
#                                       0 | 0 == 0,
#                                       excludes(6, 0)),
#                                   And(6 | 0 == 0,
#                                       1 | 0 == 0,
#                                       excludes(6, 1)),
#                                   And(6 | 0 == 0,
#                                       2 | 0 == 0,
#                                       excludes(6, 2)),
#                                   And(6 | 0 == 0,
#                                       3 | 0 == 0,
#                                       excludes(6, 3)),
#                                   And(6 | 0 == 0,
#                                       4 | 0 == 0,
#                                       excludes(6, 4)),
#                                   And(6 | 0 == 0,
#                                       5 | 0 == 0,
#                                       excludes(6, 5)),
#                                   And(6 | 0 == 0,
#                                       6 | 0 == 0,
#                                       excludes(6, 6)),
#                                   And(6 | 0 == 0,
#                                       7 | 0 == 0,
#                                       excludes(6, 7))),
#                                Or(And(7 | 0 == 0,
#                                       0 | 0 == 0,
#                                       excludes(7, 0)),
#                                   And(7 | 0 == 0,
#                                       1 | 0 == 0,
#                                       excludes(7, 1)),
#                                   And(7 | 0 == 0,
#                                       2 | 0 == 0,
#                                       excludes(7, 2)),
#                                   And(7 | 0 == 0,
#                                       3 | 0 == 0,
#                                       excludes(7, 3)),
#                                   And(7 | 0 == 0,
#                                       4 | 0 == 0,
#                                       excludes(7, 4)),
#                                   And(7 | 0 == 0,
#                                       5 | 0 == 0,
#                                       excludes(7, 5)),
#                                   And(7 | 0 == 0,
#                                       6 | 0 == 0,
#                                       excludes(7, 6)),
#                                   And(7 | 0 == 0,
#                                       7 | 0 == 0,
#                                       excludes(7, 7))))),
#                         Not(Or(And(And(0 | 0 == 0, 0 != 0),
#                                    Not(Or(Or(And(0 | 0 == 0,
#                                         0 | 0 == 0,
#                                         excludes(0, 0)),
#                                         And(0 | 0 == 0,
#                                         1 | 0 == 0,
#                                         excludes(0, 1)),
#                                         And(0 | 0 == 0,
# ..., And(And(Implies(And(Not(Or(Or(And(0 | 0 == 0,
#                                   0 | 0 == 0,
#                                   excludes(0, 0)),
#                               And(0 | 0 == 0,
#                                   1 | 0 == 0,
#                                   excludes(0, 1)),
#                               And(0 | 0 == 0,
#                                   2 | 0 == 0,
#                                   excludes(0, 2)),
#                               And(0 | 0 == 0,
#                                   3 | 0 == 0,
#                                   excludes(0, 3)),
#                               And(0 | 0 == 0,
#                                   4 | 0 == 0,
#                                   excludes(0, 4)),
#                               And(0 | 0 == 0,
#                                   5 | 0 == 0,
#                                   excludes(0, 5)),
#                               And(0 | 0 == 0,
#                                   6 | 0 == 0,
#                                   excludes(0, 6)),
#                               And(0 | 0 == 0,
#                                   7 | 0 == 0,
#                                   excludes(0, 7))),
#                            Or(And(1 | 0 == 0,
#                                   0 | 0 == 0,
#                                   excludes(1, 0)),
#                               And(1 | 0 == 0,
#                                   1 | 0 == 0,
#                                   excludes(1, 1)),
#                               And(1 | 0 == 0,
#                                   2 | 0 == 0,
#                                   excludes(1, 2)),
#                               And(1 | 0 == 0,
#                                   3 | 0 == 0,
#                                   excludes(1, 3)),
#                               And(1 | 0 == 0,
#                                   4 | 0 == 0,
#                                   excludes(1, 4)),
#                               And(1 | 0 == 0,
#                                   5 | 0 == 0,
#                                   excludes(1, 5)),
#                               And(1 | 0 == 0,
#                                   6 | 0 == 0,
#                                   excludes(1, 6)),
#                               And(1 | 0 == 0,
#                                   7 | 0 == 0,
#                                   excludes(1, 7))),
#                            Or(And(2 | 0 == 0,
#                                   0 | 0 == 0,
#                                   excludes(2, 0)),
#                               And(2 | 0 == 0,
#                                   1 | 0 == 0,
#                                   excludes(2, 1)),
#                               And(2 | 0 == 0,
#                                   2 | 0 == 0,
#                                   excludes(2, 2)),
#                               And(2 | 0 == 0,
#                                   3 | 0 == 0,
#                                   excludes(2, 3)),
#                               And(2 | 0 == 0,
#                                   4 | 0 == 0,
#                                   excludes(2, 4)),
#                               And(2 | 0 == 0,
#                                   5 | 0 == 0,
#                                   excludes(2, 5)),
#                               And(2 | 0 == 0,
#                                   6 | 0 == 0,
#                                   excludes(2, 6)),
#                               And(2 | 0 == 0,
#                                   7 | 0 == 0,
#                                   excludes(2, 7))),
#                            Or(And(3 | 0 == 0,
#                                   0 | 0 == 0,
#                                   excludes(3, 0)),
#                               And(3 | 0 == 0,
#                                   1 | 0 == 0,
#                                   excludes(3, 1)),
#                               And(3 | 0 == 0,
#                                   2 | 0 == 0,
#                                   excludes(3, 2)),
#                               And(3 | 0 == 0,
#                                   3 | 0 == 0,
#                                   excludes(3, 3)),
#                               And(3 | 0 == 0,
#                                   4 | 0 == 0,
#                                   excludes(3, 4)),
#                               And(3 | 0 == 0,
#                                   5 | 0 == 0,
#                                   excludes(3, 5)),
#                               And(3 | 0 == 0,
#                                   6 | 0 == 0,
#                                   excludes(3, 6)),
#                               And(3 | 0 == 0,
#                                   7 | 0 == 0,
#                                   excludes(3, 7))),
#                            Or(And(4 | 0 == 0,
#                                   0 | 0 == 0,
#                                   excludes(4, 0)),
#                               And(4 | 0 == 0,
#                                   1 | 0 == 0,
#                                   excludes(4, 1)),
#                               And(4 | 0 == 0,
#                                   2 | 0 == 0,
#                                   excludes(4, 2)),
#                               And(4 | 0 == 0,
#                                   3 | 0 == 0,
#                                   excludes(4, 3)),
#                               And(4 | 0 == 0,
#                                   4 | 0 == 0,
#                                   excludes(4, 4)),
#                               And(4 | 0 == 0,
#                                   5 | 0 == 0,
#                                   excludes(4, 5)),
#                               And(4 | 0 == 0,
#                                   6 | 0 == 0,
#                                   excludes(4, 6)),
#                               And(4 | 0 == 0,
#                                   7 | 0 == 0,
#                                   excludes(4, 7))),
#                            Or(And(5 | 0 == 0,
#                                   0 | 0 == 0,
#                                   excludes(5, 0)),
#                               And(5 | 0 == 0,
#                                   1 | 0 == 0,
#                                   excludes(5, 1)),
#                               And(5 | 0 == 0,
#                                   2 | 0 == 0,
#                                   excludes(5, 2)),
#                               And(5 | 0 == 0,
#                                   3 | 0 == 0,
#                                   excludes(5, 3)),
#                               And(5 | 0 == 0,
#                                   4 | 0 == 0,
#                                   excludes(5, 4)),
#                               And(5 | 0 == 0,
#                                   5 | 0 == 0,
#                                   excludes(5, 5)),
#                               And(5 | 0 == 0,
#                                   6 | 0 == 0,
#                                   excludes(5, 6)),
#                               And(5 | 0 == 0,
#                                   7 | 0 == 0,
#                                   excludes(5, 7))),
#                            Or(And(6 | 0 == 0,
#                                   0 | 0 == 0,
#                                   excludes(6, 0)),
#                               And(6 | 0 == 0,
#                                   1 | 0 == 0,
#                                   excludes(6, 1)),
#                               And(6 | 0 == 0,
#                                   2 | 0 == 0,
#                                   excludes(6, 2)),
#                               And(6 | 0 == 0,
#                                   3 | 0 == 0,
#                                   excludes(6, 3)),
#                               And(6 | 0 == 0,
#                                   4 | 0 == 0,
#                                   excludes(6, 4)),
#                               And(6 | 0 == 0,
#                                   5 | 0 == 0,
#                                   excludes(6, 5)),
#                               And(6 | 0 == 0,
#                                   6 | 0 == 0,
#                                   excludes(6, 6)),
#                               And(6 | 0 == 0,
#                                   7 | 0 == 0,
#                                   excludes(6, 7))),
#                            Or(And(7 | 0 == 0,
#                                   0 | 0 == 0,
#                                   excludes(7, 0)),
#                               And(7 | 0 == 0,
#                                   1 | 0 == 0,
#                                   excludes(7, 1)),
#                               And(7 | 0 == 0,
#                                   2 | 0 == 0,
#                                   excludes(7, 2)),
#                               And(7 | 0 == 0,
#                                   3 | 0 == 0,
#                                   excludes(7, 3)),
#                               And(7 | 0 == 0,
#                                   4 | 0 == 0,
#                                   excludes(7, 4)),
#                               And(7 | 0 == 0,
#                                   5 | 0 == 0,
#                                   excludes(7, 5)),
#                               And(7 | 0 == 0,
#                                   6 | 0 == 0,
#                                   excludes(7, 6)),
#                               And(7 | 0 == 0,
#                                   7 | 0 == 0,
#                                   excludes(7, 7))))),
#                     Not(Or(Or(And(0 | 0 == 0,
#                                   0 | 0 == 0,
#                                   excludes(0, 0)),
#                               And(0 | 0 == 0,
#                                   1 | 0 == 0,
#                                   excludes(0, 1)),
#                               And(0 | 0 == 0,
#                                   2 | 0 == 0,
# ..., And(Not(excludes(0, 0)),
#     Not(excludes(0, 1)),
#     Not(excludes(0, 2)),
#     Not(excludes(0, 3)),
#     Not(excludes(0, 4)),
#     Not(excludes(0, 5)),
#     Not(excludes(0, 6)),
#     Not(excludes(0, 7))), Or(And(And(And(Implies(Or(Or(And(0 | 0 == 0,
#                                  verify(0, P),
#                                  verify(0, Q)),
#                              And(0 | 1 == 0,
#                                  verify(0, P),
#                                  verify(1, Q)),
#                              And(0 | 2 == 0,
#                                  verify(0, P),
#                                  verify(2, Q)),
#                              And(0 | 3 == 0,
#                                  verify(0, P),
#                                  verify(3, Q)),
#                              And(0 | 4 == 0,
#                                  verify(0, P),
#                                  verify(4, Q)),
#                              And(0 | 5 == 0,
#                                  verify(0, P),
#                                  verify(5, Q)),
#                              And(0 | 6 == 0,
#                                  verify(0, P),
#                                  verify(6, Q)),
#                              And(0 | 7 == 0,
#                                  verify(0, P),
#                                  verify(7, Q))),
#                           Or(And(1 | 0 == 0,
#                                  verify(1, P),
#                                  verify(0, Q)),
#                              And(1 | 1 == 0,
#                                  verify(1, P),
#                                  verify(1, Q)),
#                              And(1 | 2 == 0,
#                                  verify(1, P),
#                                  verify(2, Q)),
#                              And(1 | 3 == 0,
#                                  verify(1, P),
#                                  verify(3, Q)),
#                              And(1 | 4 == 0,
#                                  verify(1, P),
#                                  verify(4, Q)),
#                              And(1 | 5 == 0,
#                                  verify(1, P),
#                                  verify(5, Q)),
#                              And(1 | 6 == 0,
#                                  verify(1, P),
#                                  verify(6, Q)),
#                              And(1 | 7 == 0,
#                                  verify(1, P),
#                                  verify(7, Q))),
#                           Or(And(2 | 0 == 0,
#                                  verify(2, P),
#                                  verify(0, Q)),
#                              And(2 | 1 == 0,
#                                  verify(2, P),
#                                  verify(1, Q)),
#                              And(2 | 2 == 0,
#                                  verify(2, P),
#                                  verify(2, Q)),
#                              And(2 | 3 == 0,
#                                  verify(2, P),
#                                  verify(3, Q)),
#                              And(2 | 4 == 0,
#                                  verify(2, P),
#                                  verify(4, Q)),
#                              And(2 | 5 == 0,
#                                  verify(2, P),
#                                  verify(5, Q)),
#                              And(2 | 6 == 0,
#                                  verify(2, P),
#                                  verify(6, Q)),
#                              And(2 | 7 == 0,
#                                  verify(2, P),
#                                  verify(7, Q))),
#                           Or(And(3 | 0 == 0,
#                                  verify(3, P),
#                                  verify(0, Q)),
#                              And(3 | 1 == 0,
#                                  verify(3, P),
#                                  verify(1, Q)),
#                              And(3 | 2 == 0,
#                                  verify(3, P),
#                                  verify(2, Q)),
#                              And(3 | 3 == 0,
#                                  verify(3, P),
#                                  verify(3, Q)),
#                              And(3 | 4 == 0,
#                                  verify(3, P),
#                                  verify(4, Q)),
#                              And(3 | 5 == 0,
#                                  verify(3, P),
#                                  verify(5, Q)),
#                              And(3 | 6 == 0,
#                                  verify(3, P),
#                                  verify(6, Q)),
#                              And(3 | 7 == 0,
#                                  verify(3, P),
#                                  verify(7, Q))),
#                           Or(And(4 | 0 == 0,
#                                  verify(4, P),
#                                  verify(0, Q)),
#                              And(4 | 1 == 0,
#                                  verify(4, P),
#                                  verify(1, Q)),
#                              And(4 | 2 == 0,
#                                  verify(4, P),
#                                  verify(2, Q)),
#                              And(4 | 3 == 0,
#                                  verify(4, P),
#                                  verify(3, Q)),
#                              And(4 | 4 == 0,
#                                  verify(4, P),
#                                  verify(4, Q)),
#                              And(4 | 5 == 0,
#                                  verify(4, P),
#                                  verify(5, Q)),
#                              And(4 | 6 == 0,
#                                  verify(4, P),
#                                  verify(6, Q)),
#                              And(4 | 7 == 0,
#                                  verify(4, P),
#                                  verify(7, Q))),
#                           Or(And(5 | 0 == 0,
#                                  verify(5, P),
#                                  verify(0, Q)),
#                              And(5 | 1 == 0,
#                                  verify(5, P),
#                                  verify(1, Q)),
#                              And(5 | 2 == 0,
#                                  verify(5, P),
#                                  verify(2, Q)),
#                              And(5 | 3 == 0,
#                                  verify(5, P),
#                                  verify(3, Q)),
#                              And(5 | 4 == 0,
#                                  verify(5, P),
#                                  verify(4, Q)),
#                              And(5 | 5 == 0,
#                                  verify(5, P),
#                                  verify(5, Q)),
#                              And(5 | 6 == 0,
#                                  verify(5, P),
#                                  verify(6, Q)),
#                              And(5 | 7 == 0,
#                                  verify(5, P),
#                                  verify(7, Q))),
#                           Or(And(6 | 0 == 0,
#                                  verify(6, P),
#                                  verify(0, Q)),
#                              And(6 | 1 == 0,
#                                  verify(6, P),
#                                  verify(1, Q)),
#                              And(6 | 2 == 0,
#                                  verify(6, P),
#                                  verify(2, Q)),
#                              And(6 | 3 == 0,
#                                  verify(6, P),
#                                  verify(3, Q)),
#                              And(6 | 4 == 0,
#                                  verify(6, P),
#                                  verify(4, Q)),
#                              And(6 | 5 == 0,
#                                  verify(6, P),
#                                  verify(5, Q)),
#                              And(6 | 6 == 0,
#                                  verify(6, P),
#                                  verify(6, Q)),
#                              And(6 | 7 == 0,
#                                  verify(6, P),
#                                  verify(7, Q))),
#                           Or(And(7 | 0 == 0,
#                                  verify(7, P),
#                                  verify(0, Q)),
#                              And(7 | 1 == 0,
#                                  verify(7, P),
#                                  verify(1, Q)),
#                              And(7 | 2 == 0,
#                                  verify(7, P),
#                                  verify(2, Q)),
#                              And(7 | 3 == 0,
#                                  verify(7, P),
#                                  verify(3, Q)),
#                              And(7 | 4 == 0,
#                                  verify(7, P),
#                                  verify(4, Q)),
#                              And(7 | 5 == 0,
#                                  verify(7, P),
#                                  verify(5, Q)),
#                              And(7 | 6 == 0,
#                                  verify(7, P),
#                                  verify(6, Q)),
#                              And(7 | 7 == 0,
#                                  verify(7, P),
#                                  verify(7, Q)))),
#                        Or(And(0 | 0 == 0,
#                               excludes(h_(ver \exclude (P \uniwedge Q), (P \uniwedge Q))(0),
#                                        0)),
#                           And(1 | 0 == 0,
#                               excludes(h_(ver \exclude (P \uniwedge Q), (P \uniwedge Q))(0),
#                                        1)),
#                           And(2 | 0 == 0,
#                               excludes(h_(ver \exclude (P \uniwedge Q), (P \uniwedge Q))(0),
# ..., Not(Or(Or(And(And(And(Implies(verify(0, P),
#                               Or(And(0 | 0 == 0,
#                                      excludes(h_(ver \exclude P, P)(0),
#                                         0)),
#                                  And(1 | 0 == 0,
#                                      excludes(h_(ver \exclude P, P)(0),
#                                         1)),
#                                  And(2 | 0 == 0,
#                                      excludes(h_(ver \exclude P, P)(0),
#                                         2)),
#                                  And(3 | 0 == 0,
#                                      excludes(h_(ver \exclude P, P)(0),
#                                         3)),
#                                  And(4 | 0 == 0,
#                                      excludes(h_(ver \exclude P, P)(0),
#                                         4)),
#                                  And(5 | 0 == 0,
#                                      excludes(h_(ver \exclude P, P)(0),
#                                         5)),
#                                  And(6 | 0 == 0,
#                                      excludes(h_(ver \exclude P, P)(0),
#                                         6)),
#                                  And(7 | 0 == 0,
#                                      excludes(h_(ver \exclude P, P)(0),
#                                         7)))),
#                       Implies(verify(1, P),
#                               Or(And(0 | 1 == 1,
#                                      excludes(h_(ver \exclude P, P)(1),
#                                         0)),
#                                  And(1 | 1 == 1,
#                                      excludes(h_(ver \exclude P, P)(1),
#                                         1)),
#                                  And(2 | 1 == 1,
#                                      excludes(h_(ver \exclude P, P)(1),
#                                         2)),
#                                  And(3 | 1 == 1,
#                                      excludes(h_(ver \exclude P, P)(1),
#                                         3)),
#                                  And(4 | 1 == 1,
#                                      excludes(h_(ver \exclude P, P)(1),
#                                         4)),
#                                  And(5 | 1 == 1,
#                                      excludes(h_(ver \exclude P, P)(1),
#                                         5)),
#                                  And(6 | 1 == 1,
#                                      excludes(h_(ver \exclude P, P)(1),
#                                         6)),
#                                  And(7 | 1 == 1,
#                                      excludes(h_(ver \exclude P, P)(1),
#                                         7)))),
#                       Implies(verify(2, P),
#                               Or(And(0 | 2 == 2,
#                                      excludes(h_(ver \exclude P, P)(2),
#                                         0)),
#                                  And(1 | 2 == 2,
#                                      excludes(h_(ver \exclude P, P)(2),
#                                         1)),
#                                  And(2 | 2 == 2,
#                                      excludes(h_(ver \exclude P, P)(2),
#                                         2)),
#                                  And(3 | 2 == 2,
#                                      excludes(h_(ver \exclude P, P)(2),
#                                         3)),
#                                  And(4 | 2 == 2,
#                                      excludes(h_(ver \exclude P, P)(2),
#                                         4)),
#                                  And(5 | 2 == 2,
#                                      excludes(h_(ver \exclude P, P)(2),
#                                         5)),
#                                  And(6 | 2 == 2,
#                                      excludes(h_(ver \exclude P, P)(2),
#                                         6)),
#                                  And(7 | 2 == 2,
#                                      excludes(h_(ver \exclude P, P)(2),
#                                         7)))),
#                       Implies(verify(3, P),
#                               Or(And(0 | 3 == 3,
#                                      excludes(h_(ver \exclude P, P)(3),
#                                         0)),
#                                  And(1 | 3 == 3,
#                                      excludes(h_(ver \exclude P, P)(3),
#                                         1)),
#                                  And(2 | 3 == 3,
#                                      excludes(h_(ver \exclude P, P)(3),
#                                         2)),
#                                  And(3 | 3 == 3,
#                                      excludes(h_(ver \exclude P, P)(3),
#                                         3)),
#                                  And(4 | 3 == 3,
#                                      excludes(h_(ver \exclude P, P)(3),
#                                         4)),
#                                  And(5 | 3 == 3,
#                                      excludes(h_(ver \exclude P, P)(3),
#                                         5)),
#                                  And(6 | 3 == 3,
#                                      excludes(h_(ver \exclude P, P)(3),
#                                         6)),
#                                  And(7 | 3 == 3,
#                                      excludes(h_(ver \exclude P, P)(3),
#                                         7)))),
#                       Implies(verify(4, P),
#                               Or(And(0 | 4 == 4,
#                                      excludes(h_(ver \exclude P, P)(4),
#                                         0)),
#                                  And(1 | 4 == 4,
#                                      excludes(h_(ver \exclude P, P)(4),
#                                         1)),
#                                  And(2 | 4 == 4,
#                                      excludes(h_(ver \exclude P, P)(4),
#                                         2)),
#                                  And(3 | 4 == 4,
#                                      excludes(h_(ver \exclude P, P)(4),
#                                         3)),
#                                  And(4 | 4 == 4,
#                                      excludes(h_(ver \exclude P, P)(4),
#                                         4)),
#                                  And(5 | 4 == 4,
#                                      excludes(h_(ver \exclude P, P)(4),
#                                         5)),
#                                  And(6 | 4 == 4,
#                                      excludes(h_(ver \exclude P, P)(4),
#                                         6)),
#                                  And(7 | 4 == 4,
#                                      excludes(h_(ver \exclude P, P)(4),
#                                         7)))),
#                       Implies(verify(5, P),
#                               Or(And(0 | 5 == 5,
#                                      excludes(h_(ver \exclude P, P)(5),
#                                         0)),
#                                  And(1 | 5 == 5,
#                                      excludes(h_(ver \exclude P, P)(5),
#                                         1)),
#                                  And(2 | 5 == 5,
#                                      excludes(h_(ver \exclude P, P)(5),
#                                         2)),
#                                  And(3 | 5 == 5,
#                                      excludes(h_(ver \exclude P, P)(5),
#                                         3)),
#                                  And(4 | 5 == 5,
#                                      excludes(h_(ver \exclude P, P)(5),
#                                         4)),
#                                  And(5 | 5 == 5,
#                                      excludes(h_(ver \exclude P, P)(5),
#                                         5)),
#                                  And(6 | 5 == 5,
#                                      excludes(h_(ver \exclude P, P)(5),
#                                         6)),
#                                  And(7 | 5 == 5,
#                                      excludes(h_(ver \exclude P, P)(5),
#                                         7)))),
#                       Implies(verify(6, P),
#                               Or(And(0 | 6 == 6,
#                                      excludes(h_(ver \exclude P, P)(6),
#                                         0)),
#                                  And(1 | 6 == 6,
#                                      excludes(h_(ver \exclude P, P)(6),
#                                         1)),
#                                  And(2 | 6 == 6,
#                                      excludes(h_(ver \exclude P, P)(6),
#                                         2)),
#                                  And(3 | 6 == 6,
#                                      excludes(h_(ver \exclude P, P)(6),
#                                         3)),
#                                  And(4 | 6 == 6,
#                                      excludes(h_(ver \exclude P, P)(6),
#                                         4)),
#                                  And(5 | 6 == 6,
#                                      excludes(h_(ver \exclude P, P)(6),
#                                         5)),
#                                  And(6 | 6 == 6,
#                                      excludes(h_(ver \exclude P, P)(6),
#                                         6)),
#                                  And(7 | 6 == 6,
#                                      excludes(h_(ver \exclude P, P)(6),
#                                         7)))),
#                       Implies(verify(7, P),
#                               Or(And(0 | 7 == 7,
#                                      excludes(h_(ver \exclude P, P)(7),
#                                         0)),
#                                  And(1 | 7 == 7,
#                                      excludes(h_(ver \exclude P, P)(7),
#                                         1)),
#                                  And(2 | 7 == 7,
#                                      excludes(h_(ver \exclude P, P)(7),
#                                         2)),
#                                  And(3 | 7 == 7,
#                                      excludes(h_(ver \exclude P, P)(7),
#                                         3)),
#                                  And(4 | 7 == 7,
#                                      excludes(h_(ver \exclude P, P)(7),
#                                         4)),
#                                  And(5 | 7 == 7,
#                                      excludes(h_(ver \exclude P, P)(7),
#                                         5)),
#                                  And(6 | 7 == 7,
#                                      excludes(h_(ver \exclude P, P)(7),
#                                         6)),
#                                  And(7 | 7 == 7,
#                                      excludes(h_(ver \exclude P, P)(7),
#                                         7))))),
# ...]

# %% [markdown]
# These may seem initially opaque, so it is recommended to see the specific implementations of constraints in the `Semantics` object and `Proposition` object you have. Additionally note that any quantifiers in definitions are finite—i.e. we do not use the default quantifiers from 'z3'. This is because this is much faster for small state spaces.
#
# Now we define the model structure. This will be user-defined (?), but mostly just for printing; the bulk of it is defined in the `ModelDefaults` class of the `model.py` module of `model_checker`. We also need to feed in some settings; we can use the settings from above as default in case we don't want anything interesting.
#
# Defining this object automatically solves the constraints and finds a model. (i.e. this is where the Z3 magic happens) We can print the `z3` model—which is sometimes useful for debugging—if a model was found or the `z3` `unsat_core` (see here for more details: https://z3prover.github.io/api/html/ml/Z3.Solver.html) if no model was found. We can also print the model in a user-friendly way, which is what the last step does.
#
# There are many user-useful print methods defined in the model structure, both in the theory-specific object (entire point of defining this object) and the default (in the position mentioned in the second paragraph). It is recommended to look at those.

# %%
model_structure = exclusion.ExclusionStructure(model_constraints, settings)
# NOTE: below not working because 'expectation' key not in settings
# model_structure.print_model() # prints the z3 model or the unsat core, depending on if model found
model_structure.print_all(settings, "DeMorgan's", "Exclusion Semantics")
# Out:
# ========================================
#
# EXAMPLE DeMorgan's: there is no countermodel.
#
# Atomic States: 3
#
# Semantic Theory: Exclusion Semantics
#
# Premise:
# 1. \exclude (P \uniwedge Q)
#
# Conclusion:
# 2. (\exclude P \univee \exclude Q)
#
# Z3 Run Time: 0.0185 seconds
#
# ========================================

# %% [markdown]
# No countermodels found, as desired! Now we will try a different theorem, for which we expect countermodels in the exclusion semantics. Namely, the propositional equivalence between the two sides of DeMorgan's tested above. The good thing is, we only need to redefined the `Syntax` object, `ModelConstraints` object, and the `ModelStructure` object—the semantics and proposition class are reusable from before, highlighting the convenient modularity of the `model_checker`!

# %%
premises2 = ["(\\exclude (P \\uniwedge Q) \\uniequiv (\\exclude P \\univee \\exclude Q))"]
conclusions2 = []

DEFAULT_GENERAL_SETTINGS = {
        "print_impossible": False,
        "print_constraints": False,
        "print_z3": False,
        "save_output": False,
        "maximize": False,
    }

for key in DEFAULT_GENERAL_SETTINGS:
    settings[key] = DEFAULT_GENERAL_SETTINGS[key]

syntax2 = mc.syntactic.Syntax(premises2, conclusions2, operators)
model_constraints2 = mc.model.ModelConstraints(settings, syntax2, semantics, proposition_class)
model_structure2 = exclusion.ExclusionStructure(model_constraints2, settings)
model_structure2.print_all(settings, "DeMorgan's Identity", "Exclusion Semantics")
# Out:
# ========================================
#
# EXAMPLE DeMorgan's Identity: there is a countermodel.
#
# Atomic States: 3
#
# Semantic Theory: Exclusion Semantics
#
# Premise:
# 1. (\exclude (P \uniwedge Q) \uniequiv (\exclude P \univee \exclude Q))
#
# Z3 Run Time: 0.0153 seconds
#
# ========================================
#
# State Space
#   #b000 = □
#   #b001 = a
#   #b010 = b
#   #b011 = a.b (world)
#   #b100 = c (world)
#
# Conflicts
#   a conflicts with c
#   a conflicts with a.c
#   a conflicts with b.c
#   a conflicts with a.b.c
#   b conflicts with c
#   b conflicts with a.c
#   b conflicts with b.c
#   b conflicts with a.b.c
#   a.b conflicts with c
#   a.b conflicts with a.c
#   a.b conflicts with b.c
#   a.b conflicts with a.b.c
#   c conflicts with a
#   c conflicts with b
#   c conflicts with a.b
#   c conflicts with a.c
#   c conflicts with b.c
#   c conflicts with a.b.c
#   a.c conflicts with a
#   a.c conflicts with b
#   a.c conflicts with a.b
#   a.c conflicts with c
#   a.c conflicts with a.c
#   a.c conflicts with b.c
#   a.c conflicts with a.b.c
#   b.c conflicts with a
#   b.c conflicts with b
#   b.c conflicts with a.b
#   b.c conflicts with c
#   b.c conflicts with a.c
#   b.c conflicts with b.c
#   b.c conflicts with a.b.c
#   a.b.c conflicts with a
#   a.b.c conflicts with b
#   a.b.c conflicts with a.b
#   a.b.c conflicts with c
#   a.b.c conflicts with a.c
#   a.b.c conflicts with b.c
#   a.b.c conflicts with a.b.c
#
# Coherence
#   □ coheres with □
#   □ coheres with a
#   □ coheres with b
#   □ coheres with a.b
#   □ coheres with c
#   □ coheres with a.c
#   □ coheres with b.c
#   □ coheres with a.b.c
#   a coheres with □
#   a coheres with a
#   a coheres with b
#   a coheres with a.b
#   b coheres with □
#   b coheres with a
#   b coheres with b
#   b coheres with a.b
#   a.b coheres with □
#   a.b coheres with a
#   a.b coheres with b
#   a.b coheres with a.b
#   c coheres with □
#   c coheres with c
#   a.c coheres with □
#   b.c coheres with □
#   a.b.c coheres with □
#
# Exclusion
#   a excludes c
#   b excludes c
#   c excludes a
#   c excludes b
#
# Functions
#   h_(t_id_x, (P \uniwedge Q)): □ → a.c
#   h_(t_id_x, (P \uniwedge Q)): a → a.c
#   h_(t_id_x, (P \uniwedge Q)): b → a.c
#   h_(t_id_x, (P \uniwedge Q)): a.b → a.c
#   h_(t_id_x, (P \uniwedge Q)): c → a.c
#   h_(t_id_x, (P \uniwedge Q)): a.c → a.c
#   h_(t_id_x, (P \uniwedge Q)): b.c → a.c
#   h_(t_id_x, (P \uniwedge Q)): a.b.c → a.c
#   h_(t_id_x, P): □ → □
#   h_(t_id_x, P): a → □
#   h_(t_id_x, P): b → □
#   h_(t_id_x, P): a.b → □
#   h_(t_id_x, P): c → □
#   h_(t_id_x, P): a.c → □
#   h_(t_id_x, P): b.c → □
#   h_(t_id_x, P): a.b.c → □
#   h_(t_id_x, Q): □ → b
#   h_(t_id_x, Q): a → b
#   h_(t_id_x, Q): b → b
#   h_(t_id_x, Q): a.b → b
#   h_(t_id_x, Q): c → b
#   h_(t_id_x, Q): a.c → b
#   h_(t_id_x, Q): b.c → b
#   h_(t_id_x, Q): a.b.c → b
#
# The evaluation world is: c
#
# INTERPRETED PREMISE:
#
# 1.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 18
#      16 model_constraints2 = mc.model.ModelConstraints(settings, syntax2, semantics, proposition_class)
#      17 model_structure2 = exclusion.ExclusionStructure(model_constraints2, settings)
# ---> 18 model_structure2.print_all(settings, "DeMorgan's Identity", "Exclusion Semantics")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/model_checker/theory_lib/exclusion/semantic.py:793, in ExclusionStructure.print_all(self, default_settings, example_name, theory_name, output)
#     791 self.print_exclusion(output)
#     792 self.print_evaluation(output)
# --> 793 self.print_input_sentences(output)
#     794 self.print_model(output)
#     795 if output is sys.__stdout__:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/model_checker/model.py:1067, in ModelDefaults.print_input_sentences(self, output)
#    1064             print(file=output)
#    1066 start_index = 1
# -> 1067 print_sentences(
#    1068     "INTERPRETED PREMISE:\n",
#    1069     "INTERPRETED PREMISES:\n",
#    1070     self.premises,
#    1071     start_index,
#    1072     output
#    1073 )
#    1074 continue_index = len(self.premises) + 1
#    1075 print_sentences(
#    1076     "INTERPRETED CONCLUSION:\n",
#    1077     "INTERPRETED CONCLUSIONS:\n",
#    (...)
#    1080     output
#    1081 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/model_checker/model.py:1063, in ModelDefaults.print_input_sentences.<locals>.print_sentences(title_singular, title_plural, sentences, start_index, destination)
#    1061 with redirect_stdout(destination):
#    1062     use_colors = output is sys.__stdout__
# -> 1063     self.recursive_print(sentence, self.main_point, 1, use_colors)
#    1064     print(file=output)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/model_checker/model.py:1029, in ModelDefaults.recursive_print(self, sentence, eval_point, indent_num, use_colors)
#    1027     return
#    1028 operator = sentence.original_operator
# -> 1029 operator.print_method(sentence, eval_point, indent_num, use_colors)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/model_checker/theory_lib/exclusion/operators.py:234, in UniIdentityOperator.print_method(self, sentence_obj, eval_point, indent_num, use_colors)
#     231 def print_method(self, sentence_obj, eval_point, indent_num, use_colors):
#     232     """Prints the proposition for sentence_obj, increases the indentation
#     233     by 1, and prints both of the arguments."""
# --> 234     self.general_print(sentence_obj, eval_point, indent_num, use_colors)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/model_checker/syntactic.py:320, in Operator.general_print(self, sentence_obj, eval_point, indent_num, use_colors)
#     305 """Prints a general evaluation of a sentence at a given evaluation point.
#     306
#     307 This method provides a standard way to print a sentence's evaluation results,
#    (...)
#     317 point, then recursively prints all subformulas (if any) with increased indentation.
#     318 """
#     319 proposition = sentence_obj.proposition
# --> 320 model_structure = proposition.model_structure
#     322 proposition.print_proposition(eval_point, indent_num, use_colors)
#     323 indent_num += 1
#
# AttributeError: 'NoneType' object has no attribute 'model_structure'
